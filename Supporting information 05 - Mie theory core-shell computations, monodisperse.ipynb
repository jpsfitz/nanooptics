# %% [markdown]
# # Table of Contents
#  <p><div class="lev1 toc-item"><a href="#Optical-properties-of-responsive-hybrid-Au@polymer-nanoparticles" data-toc-modified-id="Optical-properties-of-responsive-hybrid-Au@polymer-nanoparticles-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Optical properties of responsive hybrid Au@polymer nanoparticles</a></div><div class="lev2 toc-item"><a href="#Supporting-information---Collapsed-shell-reference-state" data-toc-modified-id="Supporting-information---Collapsed-shell-reference-state-11"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Supporting information - Collapsed shell reference state</a></div><div class="lev2 toc-item"><a href="#Abstract" data-toc-modified-id="Abstract-12"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Abstract</a></div><div class="lev1 toc-item"><a href="#Initialize-analysis" data-toc-modified-id="Initialize-analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Initialize analysis</a></div><div class="lev2 toc-item"><a href="#Initialize-computational/python-framework" data-toc-modified-id="Initialize-computational/python-framework-21"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Initialize computational/python framework</a></div><div class="lev2 toc-item"><a href="#Import-UV-vis,-DLS,-SLS-data" data-toc-modified-id="Import-UV-vis,-DLS,-SLS-data-22"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Import UV-vis, DLS, SLS data</a></div><div class="lev2 toc-item"><a href="#Peak-Analysis,-data:-Power-law-baseline-for-scattering-correction" data-toc-modified-id="Peak-Analysis,-data:-Power-law-baseline-for-scattering-correction-23"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Peak Analysis, data: Power law baseline for scattering correction</a></div><div class="lev3 toc-item"><a href="#Core-spectrum-analysis-(in-water)" data-toc-modified-id="Core-spectrum-analysis-(in-water)-231"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Core spectrum analysis (in water)</a></div><div class="lev4 toc-item"><a href="#Core-spectrum-without-power-law-baseline" data-toc-modified-id="Core-spectrum-without-power-law-baseline-2311"><span class="toc-item-num">2.3.1.1&nbsp;&nbsp;</span>Core spectrum without power law baseline</a></div><div class="lev4 toc-item"><a href="#Power-law-baseline-of-core-spectrum,-for-later-correction" data-toc-modified-id="Power-law-baseline-of-core-spectrum,-for-later-correction-2312"><span class="toc-item-num">2.3.1.2&nbsp;&nbsp;</span>Power law baseline of core spectrum, for later correction</a></div><div class="lev3 toc-item"><a href="#Core-shell" data-toc-modified-id="Core-shell-232"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Core-shell</a></div><div class="lev1 toc-item"><a href="#Mie-theory:-Au-polymer-core-shells-in-water" data-toc-modified-id="Mie-theory:-Au-polymer-core-shells-in-water-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Mie theory: Au-polymer core-shells in water</a></div><div class="lev3 toc-item"><a href="#'Soft'-shells-vs.-'hard'-shells" data-toc-modified-id="'Soft'-shells-vs.-'hard'-shells-301"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>'Soft' shells vs. 'hard' shells</a></div><div class="lev2 toc-item"><a href="#Computation:-Extinction-cross-section" data-toc-modified-id="Computation:-Extinction-cross-section-31"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Computation: Extinction cross section</a></div><div class="lev3 toc-item"><a href="#First-computation" data-toc-modified-id="First-computation-311"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>First computation</a></div><div class="lev4 toc-item"><a href="#Input-parameter-ranges" data-toc-modified-id="Input-parameter-ranges-3111"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>Input parameter ranges</a></div><div class="lev4 toc-item"><a href="#Input-parameter-array-and-computation-algorithm-definition" data-toc-modified-id="Input-parameter-array-and-computation-algorithm-definition-3112"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>Input parameter array and computation algorithm definition</a></div><div class="lev4 toc-item"><a href="#Test-and-time-algorithm" data-toc-modified-id="Test-and-time-algorithm-3113"><span class="toc-item-num">3.1.1.3&nbsp;&nbsp;</span>Test and time algorithm</a></div><div class="lev4 toc-item"><a href="#Run-full-computation" data-toc-modified-id="Run-full-computation-3114"><span class="toc-item-num">3.1.1.4&nbsp;&nbsp;</span>Run full computation</a></div><div class="lev4 toc-item"><a href="#Save-results-to-file" data-toc-modified-id="Save-results-to-file-3115"><span class="toc-item-num">3.1.1.5&nbsp;&nbsp;</span>Save results to file</a></div><div class="lev2 toc-item"><a href="#Differences-between-cross-sections" data-toc-modified-id="Differences-between-cross-sections-32"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Differences between cross sections</a></div><div class="lev3 toc-item"><a href="#Difference-between-core-shell-and-core-+-shell" data-toc-modified-id="Difference-between-core-shell-and-core-+-shell-321"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Difference between core-shell and core + shell</a></div><div class="lev3 toc-item"><a href="#Difference-between-shell-and-swollen-shell" data-toc-modified-id="Difference-between-shell-and-swollen-shell-322"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Difference between shell and swollen shell</a></div><div class="lev3 toc-item"><a href="#Difference-between-core-shell-and-swollen-core-shell" data-toc-modified-id="Difference-between-core-shell-and-swollen-core-shell-323"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Difference between core-shell and swollen core-shell</a></div><div class="lev1 toc-item"><a href="#Peak-Analysis:-Power-law-baseline-for-scattering-correction" data-toc-modified-id="Peak-Analysis:-Power-law-baseline-for-scattering-correction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Peak Analysis: Power law baseline for scattering correction</a></div><div class="lev2 toc-item"><a href="#Peak-analysis" data-toc-modified-id="Peak-analysis-41"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Peak analysis</a></div><div class="lev3 toc-item"><a href="#Core-spectrum-analysis-(in-water)" data-toc-modified-id="Core-spectrum-analysis-(in-water)-411"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Core spectrum analysis (in water)</a></div><div class="lev4 toc-item"><a href="#Core-spectrum-without-power-law-baseline" data-toc-modified-id="Core-spectrum-without-power-law-baseline-4111"><span class="toc-item-num">4.1.1.1&nbsp;&nbsp;</span>Core spectrum without power law baseline</a></div><div class="lev4 toc-item"><a href="#Power-law-baseline-of-core-spectrum,-for-later-correction" data-toc-modified-id="Power-law-baseline-of-core-spectrum,-for-later-correction-4112"><span class="toc-item-num">4.1.1.2&nbsp;&nbsp;</span>Power law baseline of core spectrum, for later correction</a></div><div class="lev3 toc-item"><a href="#Core-shell-spectrum-analysis" data-toc-modified-id="Core-shell-spectrum-analysis-412"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Core-shell spectrum analysis</a></div><div class="lev4 toc-item"><a href="#Hard-sphere" data-toc-modified-id="Hard-sphere-4121"><span class="toc-item-num">4.1.2.1&nbsp;&nbsp;</span>Hard sphere</a></div><div class="lev4 toc-item"><a href="#Soft-sphere" data-toc-modified-id="Soft-sphere-4122"><span class="toc-item-num">4.1.2.2&nbsp;&nbsp;</span>Soft sphere</a></div><div class="lev3 toc-item"><a href="#Core-spectrum-analysis,-in-shell-like-medium" data-toc-modified-id="Core-spectrum-analysis,-in-shell-like-medium-413"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Core spectrum analysis, in shell-like medium</a></div><div class="lev4 toc-item"><a href="#Core-spectrum-without-power-law-baseline" data-toc-modified-id="Core-spectrum-without-power-law-baseline-4131"><span class="toc-item-num">4.1.3.1&nbsp;&nbsp;</span>Core spectrum without power law baseline</a></div><div class="lev2 toc-item"><a href="#Peak-wavelength-plot" data-toc-modified-id="Peak-wavelength-plot-42"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Peak wavelength plot</a></div><div class="lev3 toc-item"><a href="#Simple,-unformatted" data-toc-modified-id="Simple,-unformatted-421"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Simple, unformatted</a></div><div class="lev3 toc-item"><a href="#Formatted" data-toc-modified-id="Formatted-422"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Formatted</a></div><div class="lev2 toc-item"><a href="#Peak-vs-LSPR-wavelength-plot" data-toc-modified-id="Peak-vs-LSPR-wavelength-plot-43"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Peak vs LSPR wavelength plot</a></div><div class="lev3 toc-item"><a href="#Simple,-unformatted" data-toc-modified-id="Simple,-unformatted-431"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Simple, unformatted</a></div><div class="lev3 toc-item"><a href="#Formatted,-vs-wavelength" data-toc-modified-id="Formatted,-vs-wavelength-432"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Formatted, vs wavelength</a></div><div class="lev3 toc-item"><a href="#Formatted,-vs-change-in-wavelength" data-toc-modified-id="Formatted,-vs-change-in-wavelength-433"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Formatted, vs change in wavelength</a></div>

# %% [markdown]
# Optical properties of responsive hybrid Au@polymer nanoparticles
# ========

# %% [markdown]
# Must change title eventually

# %% [markdown]
# Supporting information - Collapsed shell reference state
# --------

# %% [markdown]
# Abstract
# --------

# %% [markdown]
# The Au@PNIPAM collapsed shells (at high temperature) can be treated as (nearly) solid shells. Here the UV-vis and SLS data (where available) is compared to Mie theory.

# %% [markdown]
# # Initialize analysis

# %% [markdown]
# ## Initialize computational/python framework

# %%
# %run header
# Out:
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.

# %%
# %run header_parallel
# %px %run header
# Out:
# Initializing cluster ...
#    Client variable 'kernels'
#    Cluster Direct View variable 'cluster'
#    Variable 'nKernels' = 7
# importing os on engine(s)
# [stdout:0]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.
# [stdout:1]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.
# [stdout:2]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.
# [stdout:3]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.
# [stdout:4]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.
# [stdout:5]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.
# [stdout:6]
# Loading import modules ...
#   ... math, cmath (local)
#   ... os, sys, types, importlib
#   ... time, datetime
#   ... ipyparallel as ipp
#   ... numpy as np
#   ... scipy as sp
#       scipy.special (local, for Bessel functions)
#       scipy.interpolate as interpolate
#       scipy.signal as signal
#   ... matplotlib
#       matplotlib.pyplot as plt
#       matplotlib.cm as cm
#       matplotlib.pylab as pylab
#   ... peakutils
# Defining fundamental constants ...
#   ... Avogadro's number: 'AvogadroN'
#   ... speed of light: 'cumfs','cnmfs'
#   ... Planck's constant: 'heVfs','hbareVfs'
#   ... electron rest mass: 'eMass0eVnmfs'
#   ... permittivity of free space: 'eps0enmV'
# Loading analysis codes ...
#   ... refractive index functions loaded:
#        Au, Ag, SiO2, ITO, ZnO, H2O,
#        ethanol, CS2, benzene, toluene,
#        chloroform, methanol, butanol,
#        propanol
#   ... Mie functions loaded
# Ready player one.

# %% [markdown]
# ## Import UV-vis, DLS, SLS data

# %%
# %run -i header_import_data
# Out:
# Import and organize data
# ========================
# Linear PNIPAM:
# Importing data in folder data_20160905 ...
#   * Au-linPNIPAM-long-hydr-radius.dat
#   * Au-linPNIPAM-long.dat
#   * Au-linPNIPAM-medium-hydr-radius.dat
#   * Au-linPNIPAM-medium.dat
#   * Au-linPNIPAM-short-hydr-radius.dat
#   * Au-linPNIPAM-short.dat
#   * core-spectrum-AW5.txt
# Oganizing data ...
#   * extrapolate hydrodynamic radius from DLS to UV-Vis temps
#   * organized as [ wl-nm, abs, temp, Rh, sample-# ]
#   * sample 2 = thick shell, 1 = medium, 0 = thin
#   * core alone sorted separately
# Done.
#
# Import and organize data
# ========================
# X-linked PNIPAM:
# Importing data in folder data_20160906 ...
#   * Au-core-only-for-xPNIPAM.dat
#   * Au-xPNIPAM-long-hydr-radius.dat
#   * Au-xPNIPAM-long.dat
#   * Au-xPNIPAM-medium-hydr-radius.dat
#   * Au-xPNIPAM-medium.dat
#   * Au-xPNIPAM-short-hydr-radius.dat
#   * Au-xPNIPAM-short.dat
#   * temperature-calibration.dat
# Oganizing data ...
#   * extrapolate hydrodynamic radius from DLS to UV-Vis temps
#   * organized as [ wl-nm, abs, temp, Rh, sample-# ]
#   * sample 5 = thick shell, 4 = medium, 3 = thin
#   * core alone sorted separately
# Done.
#
# Combining data sets...
# 0 :	 13 temperatures
# 1 :	 13 temperatures
# 2 :	 12 temperatures
# 3 :	 21 temperatures
# 4 :	 21 temperatures
# 5 :	 21 temperatures
#
# Import and organize data
# ========================
# X-linked PNIPAM:
# Importing data in folder data_20160914 ...
#   * Au-xPNIPAM-long-SLS-20degreeC.dat
#   * Au-xPNIPAM-long-SLS-50degreeC.dat
#   * Au-xPNIPAM-medium-SLS-20degreeC.dat
#   * Au-xPNIPAM-medium-SLS-50degreeC.dat
#   * Au-xPNIPAM-short-SLS-20degreeC.dat
# Columns: ['theta', 'q', 'I(q)', 'I(q)-error']
# Collapsed-state reference samples 4-5
#
#
# Variables:
#   * indexes:
#     - "coreNum" (2):
#       (0=Lin),	(1=X-L)
#     - "sampleNum" (6):
#       (0=L-Thn),	(1=L-Med),	(2=L-Thk),
#       (3=X-Thn),	(4=X-Med),	5=(X-Thk)
#   * "spectraCores" = core spectra
#     - type:	 <class 'numpy.ndarray'>
#     - size:	 (2, 911, 2)
#     - [coreNum]  x  [wl-index]  x  [ wl-nm, ext-au ]
#   * "coreRnms" = core radiuses
#     - type:	 <class 'list'>
#     - size:	 (2,)
#     - [coreNum] x [core-radius-TEM-nm]
#   * "dataArray" = core-shell spectra
#     - type:	 <class 'numpy.ndarray'>
#     - size:	 (92011, 5)
#     - [data-index]  x  [ wl-nm, ext-au, temp-C, Rh-nm, sampleNum ]
#   * "spectraTemps" = core-shell temperatures
#     - type:	 <class 'numpy.ndarray'>
#     - size:	 (6,)
#     - [sampleNum]  x  [ temp-C ]
#   * "spectraRhnms" = core-shell hydrodynamic radiuses
#     - type:	 <class 'numpy.ndarray'>
#     - size:	 (6,)
#     - [sampleNum]  x  [ Rh-nm ]
#   * "slsData" = all 5 SLS data sets, sorted as input above
#     - type:	 <class 'list'>
#     - size:	 (5,)
#     - [ theta-deg, q-nm, I(q), error-I(q) ]
#   * "slsIvsqRefSample4" = collapsed state for sample 4 (X2-med)
#     - type:	 <class 'numpy.ndarray'>
#     - size:	 (131, 2)
#     - [ q-nm, I(q) ]
#   * "slsIvsqRefSample5" = collapsed state for sample 5 (X3-thk)
#     - type:	 <class 'numpy.ndarray'>
#     - size:	 (131, 2)
#     - [ q-nm, I(q) ]
# Done.

# %% [markdown]
# ## Peak Analysis, data: Power law baseline for scattering correction

# %% [markdown]
# ### Core spectrum analysis (in water)

# %% [markdown]
# #### Core spectrum without power law baseline

# %%
threshold = 0.25
wlExpectednm = 525
dwlExpectednm = 35
nPeaks = 1
wlMin0nm, wlMax0nm = wlExpectednm-2*dwlExpectednm, wlExpectednm+2*dwlExpectednm
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier = "_lspr-core-peaks"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'Rcore-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Bare cores only')
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('  * peaks detected: \n    wl-nm (interp),\t [wl-nm,  ext]')

lsprPeakWLnmCoreList = []
for sampleNum in range(2):
    sampleType = (['L-Core_D=','X-Core_D='][sampleNum]) + str(int(round(2*coreRnms[sampleNum]))) + '-nm'
    print('   - Core #',sampleNum,'(',
          sampleType,
          ')')
    subdataArray = spectraCores[sampleNum]
    selection = ((subdataArray[:,0] >= wlMin0nm) 
                 & (subdataArray[:,0] <= wlMax0nm)
                 )
    subdataArray = subdataArray[selection]
    minDist = int(subdataArray.size/(nPeaks+1))
    x, y = subdataArray[:,0], subdataArray[:,1]
    indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
    xPeaks = x[indexes]
    anArray = (np.array([xPeaks, indexes])).T
    selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
    indexes = (anArray[selection][:,1]).tolist()
    xPeaks = x[indexes]
    if (len(indexes) > 0): 
        result = subdataArray[indexes[0]]
        xPeaks = peakutils.interpolate(x, y, indexes)
        print('   ', round(100*xPeaks[0])/100,',\t\t',  
              (np.round(100*result)/100).tolist())
        result = [xPeaks[0], coreRnms[sampleNum]]
        lsprPeakWLnmCoreList.append(result)

#filename = folder + timestamp + identifier + exportFormat
#np.savetxt(filename, lsprPeakWLnmCoreList, delimiter='\t', header=datHeader, fmt='%.2f')
#print('     + saved to', filename) 

print("  * output array format: \n    [ peak-wl-nm, Rcore-nm]")
# Out:
# LSPR peak wavelengths
# =====================
# Bare cores only
#   * looking for one peak at 525 nm
#     - in the range [ 490 , 560 ] nm
#   * peaks detected:
#     wl-nm (interp),	 [wl-nm,  ext]
#    - Core # 0 ( L-Core_D=17-nm )
#     519.72 ,		 [519.0, 1.1]
#    - Core # 1 ( X-Core_D=13-nm )
#     517.55 ,		 [518.0, 1.44]
#   * output array format:
#     [ peak-wl-nm, Rcore-nm]

# %% [markdown]
# #### Power law baseline of core spectrum, for later correction

# %%
threshold = 0.25
wlScatnm = 400
wlExpectednm = 525
dwlExpectednm = 25
x0base = wlExpectednm
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier = "_lspr-core-peaks_baseline-powr"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'wl-orig-nm', 'Rcore-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Bare cores only')
print('  * power law baseline fit')
print('    - of the form ybase = k*(x/x0)^n')
print('    - using log-log/linear fitting with x0 =',x0base)
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('    - baseline correction range [', wlMin0nm, ',', wlMax0nm, '] nm')
print('Peaks detected: \n    wl-nm (interp),\t [wl-nm, ext], \t (orig wl-nm),\t gamma Ref')

lsprPowrPeakWLnmCoreList = []
lsprPowrBaselineCoreList = []
lsprPowrBaselineCorenkList = []
lsprPowrGammaCoreRefList = []

for sampleNum in range(2):
    sampleType = (['L-Core_D=','X-Core_D='][sampleNum]) + str(int(round(2*coreRnms[sampleNum]))) + '-nm'
    print('  * Core #',sampleNum,'(', sampleType, ')', end="")
    
    subdataArray = spectraCores[sampleNum]
    selection = ((subdataArray[:,0] >= wlMin0nm) 
                 & (subdataArray[:,0] <= wlMax0nm)
                 )
    subdataArray = subdataArray[selection]
    minDist = int(subdataArray.size/(nPeaks+1))
    
    x, y = subdataArray[:,0], subdataArray[:,1]
    yOrig = y
    logx, logy = np.log(x/x0base), np.log(y)
    dlogx = min(np.diff(logx))
    loglogx = np.arange(min(logx), max(logx) + dlogx, dlogx)
    loglogy = np.interp(loglogx, logx, logy)
    
    loglogyLinBase = peakutils.baseline(loglogy, 1)
    logyLinBase = np.interp(logx, loglogx, loglogyLinBase)
    loglogfit = np.polyfit(logx, logyLinBase, 1)
    basePowrn, baseCoeffk = loglogfit[0], np.exp(loglogfit[1])
    print('\t{baseline n =', '{0:.2f}'.format(basePowrn),', k =', '{0:.1f}'.format(baseCoeffk),'}')
    
    yPowrBase = (np.exp(logyLinBase))
    y = y - yPowrBase
    
    indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
    xPeaks = x[indexes]
    anArray = (np.array([xPeaks, indexes])).T
    selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
    indexes = (anArray[selection][:,1]).tolist()
    xPeaks = x[indexes]
    if (len(indexes) > 0): 
        result = subdataArray[indexes[0]]
        xPeaks = peakutils.interpolate(x, y, indexes)

        xPeak = xPeaks[0]
        xPeakOrig = lsprPeakWLnmCoreList[sampleNum][0]
        select = (np.abs(x-xPeak) < 0.55)
        subdataArrayPeak = subdataArray[select][0]
        select = (np.abs(x-wlScatnm) < 0.55)
        subdataArrayScat = subdataArray[select][0]
        gammaCoreRef = subdataArrayPeak[1]/subdataArrayScat[1]

        print('   ', round(100*xPeaks[0])/100,',\t',  
              (np.round(100*subdataArrayPeak[:])/100).tolist(),
              '\t (',round(100*xPeakOrig)/100,')',
              '\t',(np.round(100*subdataArrayScat[:])/100).tolist(),
              '\t {0:.3f} '.format(gammaCoreRef))
        
        
        result = [xPeaks[0], lsprPeakWLnmCoreList[sampleNum][0], coreRnms[sampleNum]]
        lsprPowrPeakWLnmCoreList.append(result)

        resultGamma = [result[0], subdataArrayPeak[1], subdataArrayScat[1], 
                       gammaCoreRef, result[-1]]
        lsprPowrGammaCoreRefList.append(resultGamma)

        lsprPowrBaselineCoreList.append([x, yOrig, y[indexes][0], y, yPowrBase])
        lsprPowrBaselineCorenkList.append([x0base, basePowrn, baseCoeffk])

filename = folder + timestamp + identifier + exportFormat
#np.savetxt(filename, lsprPowrPeakWLnmCoreList, delimiter='\t', header=datHeader, fmt='%.2f')
#print('     + saved to', filename) 
print('variable: \t lsprPowrPeakWLnmCoreList')
print("  * output array format: \n    [ peak-wl-nm, orig-peak-wl-nm, Rcore-nm ]")
print('variable: \t lsprPowrBaselineCoreList')
print("  * output array format: \n    [ wl-nm-data, ext-data, peak-corr-ext",
      "ext-corrected-data, baseline-correction-data]")
print('  * wavelength range: [',lsprPowrBaselineCoreList[0][0][0],',', 
      lsprPowrBaselineCoreList[0][0][-1],'] x (',len(lsprPowrBaselineCoreList[0][0]), 'values)')
print('variable: \t lsprPowrBaselineCorenkList')
print("  * output array format: \n    [ x0, n, k ]")
print('variable: \t lsprPowrGammaCoreRefList')
print("  * output array format: \n    [ peak-wl-nm, ext-peak, ext-"+str(wlScatnm)+"-nm, gamma-core-Ref, Rcore-nm ]")
# Out:
# LSPR peak wavelengths
# =====================
# Bare cores only
#   * power law baseline fit
#     - of the form ybase = k*(x/x0)^n
#     - using log-log/linear fitting with x0 = 525
#   * looking for one peak at 525 nm
#     - in the range [ 500 , 550 ] nm
#     - baseline correction range [ 400 , 800 ] nm
# Peaks detected:
#     wl-nm (interp),	 [wl-nm, ext], 	 (orig wl-nm),	 gamma Ref
#   * Core # 0 ( L-Core_D=17-nm )	{baseline n = -4.74 , k = 0.2 }
#     521.21 ,	 [521.0, 1.1] 	 ( 519.72 ) 	 [400.0, 0.67] 	 1.634
#   * Core # 1 ( X-Core_D=13-nm )	{baseline n = -4.40 , k = 0.3 }
#     519.74 ,	 [520.0, 1.44] 	 ( 517.55 ) 	 [400.0, 0.95] 	 1.509
# variable: 	 lsprPowrPeakWLnmCoreList
#   * output array format:
#     [ peak-wl-nm, orig-peak-wl-nm, Rcore-nm ]
# variable: 	 lsprPowrBaselineCoreList
#   * output array format:
#     [ wl-nm-data, ext-data, peak-corr-ext ext-corrected-data, baseline-correction-data]
#   * wavelength range: [ 400.0 , 800.0 ] x ( 401 values)
# variable: 	 lsprPowrBaselineCorenkList
#   * output array format:
#     [ x0, n, k ]
# variable: 	 lsprPowrGammaCoreRefList
#   * output array format:
#     [ peak-wl-nm, ext-peak, ext-400-nm, gamma-core-Ref, Rcore-nm ]

# %% [markdown]
# ### Core-shell

# %%
threshold = 0.25
wlExpectednm = 525
dwlExpectednm = 25
wlScatnm = 400
x0base = wlExpectednm
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier0 = "lspr-peaks_baseline-powr"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'orig-wl-nm', 'temp-C', 'Rh-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Core-shell nanoparticles')
print('  * power law baseline fit')
print('    - of the form ybase = k*(x/x0)^n')
print('    - using log-log/linear fitting with x0 =',x0base)
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('    - baseline correction range [', wlMin0nm, ',', wlMax0nm, '] nm')
print('Peaks detected: \n    wl-nm,\t [wl-nm, ext, T-C, Rh-nm], \t (orig wl-nm)',
     '\t [wl-nm, ext, T-C, Rh-nm]', '\t gamma')

lsprPowrPeakWLnmList = []
lsprPowrBaselineList = []
lsprPowrBaselinenkList = []
lsprPowrBaselineExpvsScaPrmList = []
lsprPowrGammaList = []
x = []

for sampleNum in range(6):
    sampleType = (['L-Thn','L-Med','L-Thk','X-Thn','X-Med','X-Thk'][sampleNum])
    print(' * Sample #',sampleNum,'(', sampleType, ')')
    lsprPeakWLnmSubList = []
    indexT = 0
    coreNum = 0
    if sampleNum >= 3: coreNum = 1
    gammaCoreRef = lsprPowrGammaCoreRefList[coreNum][-2]
    
    for T in spectraTemps[sampleNum]:
        selection = ((dataArray[:,-1] == sampleNum) 
                     & (dataArray[:,-3] == T)
                     & (dataArray[:,0] >= wlMin0nm) 
                     & (dataArray[:,0] <= wlMax0nm)
                     )
        subdataArray = dataArray[selection]
        minDist = int(subdataArray.size/(nPeaks+1))
        
        x, y = subdataArray[:,0], subdataArray[:,1]
        yOrig = y
        logx, logy = np.log(x/x0base), np.log(y)
        dlogx = min(np.diff(logx))
        loglogx = np.arange(min(logx), max(logx) + dlogx, dlogx)
        loglogy = np.interp(loglogx, logx, logy - min(logy))

        loglogyLinBase = peakutils.baseline(loglogy, 1)
        logyLinBase = np.interp(logx, loglogx, loglogyLinBase) + min(logy)
        loglogfit = np.polyfit(logx, logyLinBase, 1)
        basePowrn0, baseCoeffk0 = loglogfit[0], np.exp(loglogfit[1])
    
        yPowrBase = (np.exp(logyLinBase))
        y = y - yPowrBase
        indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
        xPeaks = x[indexes]
        anArray = (np.array([xPeaks, indexes])).T
        selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
        indexes = (anArray[selection][:,1]).tolist()
        # if no peaks:
        if (len(indexes) == 0): 
            selection = (x >= wlMinnm) & (x <= wlMaxnm)
            xzoom, yzoom = x[selection], y[selection]
            indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
            indexes = indexeszoom + (wlMinnm - wlMin0nm)
        xPeaks = x[indexes]
                
        selection = ( (lsprPowrBaselineCoreList[coreNum][0] >= wlMin0nm)
                     & (lsprPowrBaselineCoreList[coreNum][0] <= wlMax0nm)
                     )
        yCorePowrBase = np.asarray(lsprPowrBaselineCoreList[coreNum][-1])[selection]
        yCorePeak = lsprPowrBaselineCoreList[coreNum][2]
        scaling = 1*y[indexes][0]/yCorePeak
        y = y + yCorePowrBase*scaling
        
        # fit [(base) - (core base)] to power law
        yPowrBaseTotal = yPowrBase - yCorePowrBase*scaling
        logy = np.log(yPowrBaseTotal)
        if min(yPowrBaseTotal) > 0: 
            logy = np.log(yPowrBaseTotal)
            loglogfit = np.polyfit(logx, logy, 1)
        else: loglogfit = [0, 0]
        basePowrn, baseCoeffk = loglogfit[0], np.exp(loglogfit[1])
        
        indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
        xPeaks = x[indexes]
        anArray = (np.array([xPeaks, indexes])).T
        selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
        indexes = (anArray[selection][:,1]).tolist()
        # if no peaks:
        if (len(indexes) == 0): 
            selection = (x >= wlMinnm) & (x <= wlMaxnm)
            xzoom, yzoom = x[selection], y[selection]
            indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
            indexes = indexeszoom + (wlMinnm - wlMin0nm)
        xPeaks = x[indexes]

        # iterate 
        for i in range(20):
            oldScaling = scaling
            scaling = 1*(y[indexes[0]] - yCorePowrBase[indexes[0]]*scaling)/yCorePeak
            if ( abs(1-oldScaling/scaling) < 0.000001 ): break
            
            y = yOrig - yPowrBase + yCorePowrBase*scaling
            indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
            xPeaks = x[indexes]
            anArray = (np.array([xPeaks, indexes])).T
            selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
            indexes = (anArray[selection][:,1]).tolist()
            # if no peaks:
            if (len(indexes) == 0): 
                selection = (x >= wlMinnm) & (x <= wlMaxnm)
                xzoom, yzoom = x[selection], y[selection]
                indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                indexes = indexeszoom + (wlMinnm - wlMin0nm)

        if (len(indexes) > 0): 
            result = subdataArray[indexes[0]]
            Rhnm = result[-2]
            xPeaks = peakutils.interpolate(x, y, indexes)
            indexT = indexT + 1
            
            xPeak = xPeaks[0]
            
            select = (np.abs(x-xPeak) < 0.51)
            subdataArrayPeak = subdataArray[select][0]
            select = (np.abs(x-wlScatnm) < 0.51)
            subdataArrayScat = subdataArray[select][0]
            gamma = subdataArrayPeak[1]/subdataArrayScat[1]
            gamma = gamma/gammaCoreRef
            
            print('   ', round(100*xPeaks[0])/100,',\t',  
                  (np.round(100*subdataArrayPeak[0:-1])/100).tolist(),
                  '\t',(np.round(100*subdataArrayScat[0:-1])/100).tolist(),
                  '\t {0:.3f} '.format(gamma))
            
            result = [xPeaks[0], gamma, result[-3], result[-2], int(result[-1])]
            lsprPowrPeakWLnmList.append(result)

            resultGamma = [result[0], subdataArrayPeak[1], subdataArrayScat[1], 
                           gamma, result[-3], result[-2], int(result[-1])]
            lsprPowrGammaList.append(resultGamma)

            lsprPowrBaselineList.append([x, yOrig, scaling, y, yPowrBase, 
                                         yPowrBase-yCorePowrBase*scaling])
            lsprPowrBaselinenkList.append([x0base, basePowrn0, baseCoeffk0])
            result = [xPeaks[0], result[-3], result[-2]]
            lsprPeakWLnmSubList.append(result)
            
            scatParam = 2*pi*Rhnm/(xPeaks[0]/1.35)
            lsprPowrBaselineExpvsScaPrmList.append([scatParam, basePowrn])
            
    if len(lsprPeakWLnmSubList) == 0: lsprPeakWLnmSubList.append( [0,0,0] )
    lsprPeakWLnmSubList = np.asarray(lsprPeakWLnmSubList)
    identifier = '_' + identifier0 + '_' + str(sampleNum) + '-' + sampleType
    #filename = folder + timestamp + identifier + exportFormat
    #np.savetxt(filename, lsprPeakWLnmSubList, delimiter='\t', header=datHeader, fmt='%.2f')
    #print('      + saved to', filename) 

lsprPowrPeakWLnmArray = np.asarray(lsprPowrPeakWLnmList)
lsprPowrScatGammaArray = np.asarray(lsprPowrGammaList)

print('variable: \t lsprPowrPeakWLnmArray')
print("  * output array format: \n    [ peak-wl-nm, gamma, temp-C, Rh-nm, sample-# ]")
print("    - sample-# = [0,...,5] \n      for [lin-Thin, lin-Med., lin-Long, X-Thin, X-Med., X-Long]")
print('variable: \t lsprPowrBaselineList')
print("  * output array format: \n",
      "   [ wl-nm-data, ext-orig-data, ext-scaling-factor, ext-corrected-data,",
      "baseline-correction-no-core-data, baseline-correction-data]")
print('  * wavelength range: [',x[0],',',x[-1],'] x (',len(x), 'values)')
print('variable: \t lsprPowrBaselinenkList')
print("  * output array format: \n    [ x0, n0, k0 ]")
print('variable: \t lsprPowrBaselineExpvsScaPrmList')
print("  * output array format: \n    [ ScatParam, n-exponent ]")
print('variable: \t lsprPowrScatGammaArray')
print("  * output array format: \n    [ peak-wl-nm, ext-peak, ext-"+str(wlScatnm)+"-nm, gamma, temp-C, Rh-nm, sample-# ]")
print("    - sample-# = [0,...,5] \n      for [lin-Thin, lin-Med., lin-Long, X-Thin, X-Med., X-Long]")
# Out:
# LSPR peak wavelengths
# =====================
# Core-shell nanoparticles
#   * power law baseline fit
#     - of the form ybase = k*(x/x0)^n
#     - using log-log/linear fitting with x0 = 525
#   * looking for one peak at 525 nm
#     - in the range [ 500 , 550 ] nm
#     - baseline correction range [ 400 , 800 ] nm
# Peaks detected:
#     wl-nm,	 [wl-nm, ext, T-C, Rh-nm], 	 (orig wl-nm) 	 [wl-nm, ext, T-C, Rh-nm] 	 gamma
#  * Sample # 0 ( L-Thn )
#     523.33 ,	 [523.0, 0.69, 15.0, 24.77] 	 [400.0, 0.41, 15.0, 24.77] 	 1.034
#     523.62 ,	 [524.0, 0.69, 20.0, 23.19] 	 [400.0, 0.41, 20.0, 23.19] 	 1.032
#     523.91 ,	 [524.0, 0.69, 25.0, 23.8] 	 [400.0, 0.41, 25.0, 23.8] 	 1.032
#     524.18 ,	 [524.0, 0.69, 27.0, 23.82] 	 [400.0, 0.41, 27.0, 23.82] 	 1.034
#     524.1 ,	 [524.0, 0.7, 29.0, 23.4] 	 [400.0, 0.41, 29.0, 23.4] 	 1.035
#     524.46 ,	 [524.0, 0.7, 31.0, 21.81] 	 [400.0, 0.41, 31.0, 21.81] 	 1.037
#     524.47 ,	 [524.0, 0.7, 33.0, 20.67] 	 [400.0, 0.41, 33.0, 20.67] 	 1.037
#     524.57 ,	 [525.0, 0.7, 35.0, 20.93] 	 [400.0, 0.41, 35.0, 20.93] 	 1.038
#     524.86 ,	 [525.0, 0.7, 40.0, 18.58] 	 [400.0, 0.41, 40.0, 18.58] 	 1.035
#     525.07 ,	 [525.0, 0.7, 45.0, 18.12] 	 [400.0, 0.41, 45.0, 18.12] 	 1.031
#     524.99 ,	 [525.0, 0.69, 50.0, 17.66] 	 [400.0, 0.41, 50.0, 17.66] 	 1.029
#     524.88 ,	 [525.0, 0.69, 55.0, 18.62] 	 [400.0, 0.41, 55.0, 18.62] 	 1.022
#     524.93 ,	 [525.0, 0.68, 60.0, 17.88] 	 [400.0, 0.41, 60.0, 17.88] 	 1.016
#  * Sample # 1 ( L-Med )
#     523.43 ,	 [523.0, 0.49, 15.0, 43.2] 	 [400.0, 0.29, 15.0, 43.2] 	 1.025
#     523.74 ,	 [524.0, 0.49, 20.0, 41.89] 	 [400.0, 0.29, 20.0, 41.89] 	 1.030
#     523.93 ,	 [524.0, 0.5, 25.0, 39.28] 	 [400.0, 0.29, 25.0, 39.28] 	 1.033
#     524.11 ,	 [524.0, 0.5, 27.0, 37.99] 	 [400.0, 0.3, 27.0, 37.99] 	 1.028
#     524.43 ,	 [524.0, 0.5, 29.0, 36.91] 	 [400.0, 0.3, 29.0, 36.91] 	 1.027
#     524.81 ,	 [525.0, 0.5, 31.0, 33.89] 	 [400.0, 0.3, 31.0, 33.89] 	 1.031
#     530.89 ,	 [531.0, 0.33, 33.83, 138.34] 	 [400.0, 0.66, 33.83, 138.34] 	 0.331
#     532.17 ,	 [532.0, 0.38, 36.91, 128.38] 	 [400.0, 0.77, 36.91, 128.38] 	 0.326
#     532.84 ,	 [533.0, 0.41, 40.76, 121.41] 	 [400.0, 0.85, 40.76, 121.41] 	 0.323
#     533.07 ,	 [533.0, 0.43, 44.61, 114.77] 	 [400.0, 0.88, 44.61, 114.77] 	 0.322
#     533.54 ,	 [534.0, 0.44, 48.46, 111.88] 	 [400.0, 0.9, 48.46, 111.88] 	 0.320
#     533.47 ,	 [533.0, 0.44, 52.31, 110.35] 	 [400.0, 0.91, 52.31, 110.35] 	 0.321
#     533.45 ,	 [533.0, 0.45, 56.16, 109.47] 	 [400.0, 0.92, 56.16, 109.47] 	 0.321
# variable: 	 lsprPowrPeakWLnmArray
#   * output array format:
#     [ peak-wl-nm, gamma, temp-C, Rh-nm, sample-# ]
#     - sample-# = [0,...,5]
#       for [lin-Thin, lin-Med., lin-Long, X-Thin, X-Med., X-Long]
# variable: 	 lsprPowrBaselineList
#   * output array format:
#     [ wl-nm-data, ext-orig-data, ext-scaling-factor, ext-corrected-data, baseline-correction-no-core-data, baseline-correction-data]
#   * wavelength range: [ 400.0 , 800.0 ] x ( 401 values)
# variable: 	 lsprPowrBaselinenkList
#   * output array format:
#     [ x0, n0, k0 ]
# variable: 	 lsprPowrBaselineExpvsScaPrmList
#   * output array format:
#     [ ScatParam, n-exponent ]
# variable: 	 lsprPowrScatGammaArray
#   * output array format:
#     [ peak-wl-nm, ext-peak, ext-400-nm, gamma, temp-C, Rh-nm, sample-# ]
#     - sample-# = [0,...,5]
#       for [lin-Thin, lin-Med., lin-Long, X-Thin, X-Med., X-Long]

# %% [markdown]
# # Mie theory: Au-polymer core-shells in water

# %% [markdown]
# * Refractive index of gold using:
#   - experimental tabulated data from Johnson & Christ (1972) with electron confinement effects (Bohren & Huffman 1998, Ch. 12).
# * Refractive index of shell at sampling wavelength of $\lambda_{\mathrm{SLS}}=632.8$ nm. For all other wavelengths, the refractive index dispersion is based on water: $$n(\lambda) = n_{\mathrm{H2O}}(\lambda) + [n_{\mathrm{shell}} - n_{\mathrm{H2O}}(\lambda_{\mathrm{SLS}})]$$
#   - Two refractive indexes for swollen and collapsed: $n = 1.35$ & $n = 1.42$.
# * Use hydrodynamic radius from DLS, sample along each temperature curve.
#   - monodisperse
# * Calculate core-shell and core + shell configurations.

# %% [markdown]
# ### 'Soft' shells vs. 'hard' shells

# %% [markdown]
# 'Hard' shell is a uniform density shell, with an abrupt edge at the physical, or optical radius $R$.
# 'Soft' shell has an inner and outer shell (radii $R_i < R$ and $R_o > R$, respectively),
# with the same radius of gyration $R_g$ as the hard shell.
#
# For a hard sphere, the ratio of the optical radius to the radius of gyration is $R_g/R = \sqrt{3/5} = 0.775$.
# The optical and hydrodynamic radius are nearly equivalent for a hard sphere $R_h \approx R$.
# For these PNIPAM shells, Dulle et al 2015 gives the ratio of $R_g/R_h = 0.715$,
# which is explained by a low-density outer layer.
# This gives that the radius of the outer layer $R_o = R_h$
# is $R_h/R = (0.715)\times\sqrt{3/5} = 1.084$.
#
# We assume that the thickness of the thickness of the outer layer is $2\delta R\times R$,
# where $\delta R = R_h/R - 1 = 0.0839$. Then the radius of the inner shell is slightly less than $R$,
# $R_i/R = (1-\delta R) = 0.916$.
#
# The refractive index of the inner shell is the same as the hard sphere $n_{\mathrm{shell}}$.
# The refractive index of the outer shell is taken from the density
# $n_o = (\rho_o/\rho)n_{\mathrm{shell}} + (1-\rho_o/\rho)n_{\mathrm{med}}$.
# The density ratio $\rho_o/\rho$ is computed to preserve the radius of gyration of the hard sphere.
# Using the radius of gyration formula
# $$R_g^2 = \frac{1}{M}\int r^2\,\mathrm{d}m, = \frac{4\pi\rho}{M}\int r^4\,\mathrm{d}r,$$
# this leads to $$\rho_o/\rho = \frac{ 1 - (1-\delta R)^5 }{ (1+\delta R)^5 - (1-\delta R)^5 } = 0.417.$$

# %%
RgOverRh = (54/77 + 98/135 + 129/180)/3
dR = (sqrt(3/5).real)/RgOverRh - 1
Ro = (1+dR)
R = 1
Ri = (1-dR)
Rg = (sqrt(3/5)*R).real
rhoo = ( R**5 - Ri**5 )/( Ro**5 - Ri**5 )
print((RgOverRh, dR, (Ro, R, Ri, Rg), rhoo))
# Out:
# (0.714630431297098, 0.08391223675647708, (1.083912236756477, 1, 0.9160877632435229, 0.7745966692414834), 0.4169625398201304)

# %% [markdown]
# Using the outer radius as the standard gives the adjusted values:

# %%
RgOverRh = (54/77 + 98/135 + 129/180)/3
dR = (sqrt(3/5).real)/RgOverRh - 1
Ro = 1
R = 1/(1+dR)
Ri = (1-dR)/(1+dR)
Rg = (sqrt(3/5)*R).real
rhoo = ( R**5 - Ri**5 )/( Ro**5 - Ri**5 )
print((RgOverRh, dR, (Ro, R, Ri, Rg), rhoo))
# Out:
# (0.714630431297098, 0.08391223675647708, (1, 0.922583919702228, 0.8451678394044561, 0.7146304312970979), 0.41696253982013004)

# %%
R1 = 1
R = RgOverRh/(sqrt(3/5).real)
def rho1f(R0): 
    return ( R**5 - R0**5 )/( R1**5 - R0**5 )
R0Array = np.linspace(R-2*(R1-R), R)
rho1Array = np.array(list(map(rho1f, R0Array)))
pylab.plot(R0Array, rho1Array)
pylab.show()

# %%
R1 = 1
R = RgOverRh/(sqrt(3/5).real)
dR = R1 - R
def rho1f(R0): 
    return ( R**5 - R0**5 )/( R1**5 - R0**5 )
R0Array = np.linspace(R-2*(R1-R), R)
rho1Array = np.array(list(map(rho1f, R0Array)))
pylab.plot(R0Array, rho1Array)
pylab.show()

# %% [markdown]
# ## Computation: Extinction cross section

# %% [markdown]
# ### First computation

# %% [markdown]
# #### Input parameter ranges

# %%
print("Input parameters for computation")
print("================================")

##-- parameter limits --##
# Max Mie expansion order
lmax = 5
# Wavelength range (vacuum)
wlMinnm, wlMaxnm, dwlnm = 300, 900, 1
wlListnm = np.arange(wlMinnm, wlMaxnm + 0.5*dwlnm, dwlnm)


# Shell refractive index 
# (at 632.8 nm, dispersion modeled on water)
nShellMin, nShellMax, dnShell = (ri.nH2O(632.8).real), 1.5, 0.02
nShellList = np.arange(nShellMin, nShellMax, dnShell)
print('* Shell refractive indexes based on best guess for swollen/collapsed state:\n    - n-shell = ', end='')
print(nShellList)

# Shell size, based on Rh from DLS
rShellListnm = []
rShellListnmBySample = []
rsPerSample = 5
# Set up sweep ranges
print('* Shell radii based on collapsed/intermediate/swollen state radius from DLS:\n    - Rh-nm = [', end=' ')
for sampleNum in range(6): 
    rListnm = []
    rMinnm = 0.95*np.mean(np.sort(spectraRhnms[sampleNum])[:3])
    rMaxnm = 1.05*np.mean(np.sort(spectraRhnms[sampleNum])[-3:])
    rounding = .5
    if rMaxnm > 20:  rounding = 1
    if rMaxnm > 50:  rounding = 2
    if rMaxnm > 100: rounding = 5
    if rMaxnm > 200: rounding = 10
    def generalRound(x):
        precision = -1*int(round(log(rounding,10).real))
        return np.around(rounding*np.around(x/rounding), precision)
    rMaxnm = generalRound( rMaxnm + rounding )
    rMinnm = generalRound( rMinnm - rounding )
    drnm = generalRound( (rMaxnm - rMinnm)/(rsPerSample - 1) )
    rListnm = np.arange(rMinnm, rMaxnm, drnm)
    rListnm = ( np.unique(rListnm) ).tolist()
    rShellListnmBySample.append(rListnm)
    for rnm in rListnm: 
        rShellListnm.append(rnm)
        print('{0:.1f}'.format(rnm), end='  ')
print(']')
rShellListnm = np.unique(np.array(rShellListnm))
rShellListnmBySample = np.array(rShellListnmBySample)
rShellMinnm, rShellMaxnm = min(rShellListnm), max(rShellListnm)
# Core parameters, using earlier results for Drude fit
rCoreListnm = np.asarray(coreRnms)
rCoreMinnm, rCoreMaxnm = min(rCoreListnm), max(rCoreListnm)
# Shell polydispersity
sigmaR = 0.1

# report
np.set_printoptions(precision=3)
print('''\
* Mie expansion poles     = \"lmax\"         <= {0}
* vacuum wavelengths (nm) = \"wlListnm\"     =  [{2[0]:.1f} - {2[1]:.1f}] x {3:.1f}  ({4})
* shell RI (n_shell)      = \"nShellList\"   =  [{6[0]:.3f} - {6[1]:.3f}] x {7:.3f}  ({8})
* shell radius (nm)       = \"rShellListnm\" =  [{9[0]:.1f} - {9[1]:.1f}]  ({10})
                          = \"rShellListnmBySample\" size: {11}
* core radius (nm)        = \"rCoreListnm\"  =  {12}
'''.format(lmax, 
           100*0, 
           wlListnm[[0,-1]], dwlnm, len(wlListnm), 
           0, 
           nShellList[[0,-1]], dnShell, len(nShellList), 
           rShellListnm[[0,-1]], len(rShellListnm), 
           rShellListnmBySample.shape,
           rCoreListnm,
           0,
           0,
           0,
           sigmaR*100
          )
)
# Out:
# Input parameters for computation
# ================================
# * Shell refractive indexes based on best guess for swollen/collapsed state:
#     - n-shell = [ 1.332  1.352  1.372  1.392  1.412  1.432  1.452  1.472  1.492]
# * Shell radii based on collapsed/intermediate/swollen state radius from DLS:
#     - Rh-nm = [ 16.0  18.0  20.0  22.0  24.0  24.0  29.0  34.0  39.0  44.0  34.0  42.0  50.0  58.0  66.0  46.0  56.0  66.0  76.0  86.0  70.0  90.0  110.0  130.0  150.0  100.0  120.0  140.0  160.0  180.0  ]
# * Mie expansion poles     = "lmax"         <= 5
# * vacuum wavelengths (nm) = "wlListnm"     =  [300.0 - 900.0] x 1.0  (601)
# * shell RI (n_shell)      = "nShellList"   =  [1.332 - 1.492] x 0.020  (9)
# * shell radius (nm)       = "rShellListnm" =  [16.0 - 180.0]  (27)
#                           = "rShellListnmBySample" size: (6, 5)
# * core radius (nm)        = "rCoreListnm"  =  [ 8.5  6.6]

# %% [markdown]
# #### Input parameter array and computation algorithm definition

# %%
print('''\
Set up computation algorithm
============================ \
''')

# contruct parameter list
paramList = []
for sampleNum in range(6):
    coreNum = 0
    if sampleNum > 2: coreNum = 1
    rCorenm = rCoreListnm[coreNum]
    rShellSubListnm = rShellListnmBySample[sampleNum]
    for rShellnm in rShellSubListnm:
        for nShell in nShellList:
            for wlnm in wlListnm:
                paramList.append([
                        lmax, wlnm, 
                        nShell, 
                        rShellnm, 
                        coreNum, rCorenm
                    ])
paramArray = np.asarray(paramList)
# remove duplicate entries
def uniqueRows(a):
    b = np.ascontiguousarray(a).view(np.dtype((np.void, a.dtype.itemsize * a.shape[1])))
    _, idx = np.unique(b, return_index=True)
    unique_a = np.unique(b).view(a.dtype).reshape(-1, a.shape[1])
    return unique_a
paramArray = uniqueRows(paramArray)
Nsims = len(paramArray)

print('''\
* Input variable
    - \"paramArray\" = Mie theory calculated SLS curve
    - type:\t{0}
    - size:\t{1}
* \"calcAtom\" input: 
    [   lmax, wlnm, 
        nShell, 
        rShellnm, 
        coreNum, rCorenm  ] 
'''.format(type(paramArray), np.shape(np.asarray(paramArray)) )
     )


# Independent computing unit
def calcAtom(params):
    [   lmax, wlnm, 
        nShell, 
        rShellnm, 
        coreNum, rCorenm
    ] = params
    lmax, coreNum = int(lmax), int(coreNum)
    # Au cores, J&C
    nAu = ri.nAuSc(wlnm, (4/3)*rCorenm)
    # Medium RI = water
    nmed = ( ri.nH2O(wlnm) ).real
    nmedRef = ( ri.nH2O(632.8) ).real
    # Shell RI, dispersion modeled on water
    nshell = np.real( nmed + (nShell - nmedRef) ).tolist()
    # wavenumber
    knm = 2*pi/wlnm
    
    ## extinction cross section functions 
    # monodisperse, core-shell
    def CExtMonoF(nAu, rcorenm, rshellnm):
        ns = [nAu, nshell, nmed] 
        Rnms = [rcorenm, rshellnm]
        Cext = mie.Cext(lmax, ns, Rnms, knm)
        return Cext
    # monodisperse, core only
    def CExtCoreMonoF(nAu, rcorenm, rshellnm):
        ns = [nAu, nshell] # medium with RI dispersion
        Rnms = [rcorenm]
        Cext = mie.Cext(lmax, ns, Rnms, knm)
        return Cext
    # monodisperse, shell only
    def CExtShellMonoF(nAu, rcorenm, rshellnm):
        ns = [nshell, nmed] 
        Rnms = [rshellnm]
        Cext = mie.Cext(lmax, ns, Rnms, knm)
        return Cext
    # monodisperse, core-shell, with reduced index outer shell
    # Rg/Rh matches Dulle 2015 
    # R = Ro = Rh 
    def CExtSwollenMonoF(nAu, rcorenm, rshellnm):
        RgOverRh = (54/77 + 98/135 + 129/180)/3
        dR = (sqrt(3/5).real)/RgOverRh - 1
        rOuterShellnm = rshellnm
        rInnerShellnm = rshellnm*(1-dR)/(1+dR)
        densityOuterRelative = ( (1)**5 - (1-dR)**5 )/( (1+dR)**5 - (1-dR)**5 )
        nShellOuter = densityOuterRelative*(nshell) + (1-densityOuterRelative)*nmed
        ns = [nAu, nshell, nShellOuter, nmed] 
        Rnms = [rcorenm, rInnerShellnm, rOuterShellnm]
        Cext = mie.Cext(lmax, ns, Rnms, knm)
        return Cext
    # monodisperse, shell, with reduced index outer shell
    def CExtSwollenShellMonoF(nAu, rcorenm, rshellnm):
        RgOverRh = (54/77 + 98/135 + 129/180)/3
        dR = (sqrt(3/5).real)/RgOverRh - 1
        rOuterShellnm = rshellnm
        rInnerShellnm = rshellnm*(1-dR)/(1+dR)
        densityOuterRelative = ( (1)**5 - (1-dR)**5 )/( (1+dR)**5 - (1-dR)**5 )
        nShellOuter = densityOuterRelative*(nshell) + (1-densityOuterRelative)*nmed
        ns = [nshell, nShellOuter, nmed] 
        Rnms = [rInnerShellnm, rOuterShellnm]
        Cext = mie.Cext(lmax, ns, Rnms, knm)
        return Cext
    
    # Computations
    CextMono = CExtMonoF(nAu, rCorenm, rShellnm)
    CextCoreMono = CExtCoreMonoF(nAu, rCorenm, rShellnm)
    CextShellMono = CExtShellMonoF(nAu, rCorenm, rShellnm)
    CextSwollenMono = CExtSwollenMonoF(nAu, rCorenm, rShellnm)
    CextSwollenShellMono = CExtSwollenShellMonoF(nAu, rCorenm, rShellnm)
    
    return [
        wlnm, 
        nShell, 
        rShellnm,  
        coreNum, rCorenm, 
        CextMono, 
        CextCoreMono, CextShellMono, 
        CextSwollenMono, CextSwollenShellMono
    ]

# distribute atom definition to parallel kernels
cluster.push(dict(
        calcAtom = calcAtom
    ))

print('''\
* \"calcAtom\" output: 
    [   wlnm, 
        nShell, 
        rShellnm,  
        coreNum, rCorenm, 
        CextMono (core-shell),  
        CextCoreMono, CextShellMono, 
        CextSwollenMono, CextSwollenShellMono
    ] \
''')
# Out:
# Set up computation algorithm
# ============================
# * Input variable
#     - "paramArray" = Mie theory calculated SLS curve
#     - type:	<class 'numpy.ndarray'>
#     - size:	(151452, 6)
# * "calcAtom" input:
#     [   lmax, wlnm,
#         nShell,
#         rShellnm,
#         coreNum, rCorenm  ]
#
# * "calcAtom" output:
#     [   wlnm,
#         nShell,
#         rShellnm,
#         coreNum, rCorenm,
#         CextMono (core-shell),
#         CextCoreMono, CextShellMono,
#         CextSwollenMono, CextSwollenShellMono
#     ]

# %% [markdown]
# #### Test and time algorithm

# %%
print('''\
Test algorithm  
============== \
''')

testN = 15
testParamArray = paramArray[ np.random.randint(len(paramArray), size=testN) ]
testParam = testParamArray[0]
print('''\
* timing {2} computations 
  ({1:%Y-%m-%d %H:%M:%S}) ... \
'''.format(testParam, datetime.datetime.now(), testN ), end='')

startSec = time.time()
testReturnArray = np.asarray( list( map(calcAtom, testParamArray) ) )
endSec = time.time()
dtSec = endSec - startSec
atomTimeSec = dtSec/testN
testReturn = testReturnArray[0]
print(''' done ({1:%Y-%m-%d %H:%M:%S})
    - time elapsed          =  {2:.5e} sec
    - time per computation  =  {3:.5e} sec
* using params
    [   {4[0]:.0f}, {4[1]:.1f}, 
        {4[2]:.3f}, 
        {4[3]:.1f},  
        {4[4]:.0f}, {4[5]:.1f}  ] 
* returns
    [   {0[0]:.1f},  
        {0[1]:.3f}, 
        {0[2]:.1f}, 
        {0[3]:.0f}, {0[4]:.1f}, 
        {0[5]:.5e}, 
        {0[6]:.5e}, {0[7]:.5e}, 
        {0[8]:.5e}, {0[9]:.5e}  ] \
'''.format(testReturn, datetime.datetime.now(), dtSec, atomTimeSec, testParam))

Ncluster = nKernels
estRunTimeSec = atomTimeSec*Nsims/Ncluster
m, s = divmod(estRunTimeSec, 60)
h, m = divmod(m, 60)
print('''\
* Estimated run time
    {0} computations
      @ {1:.5e} sec/comp
      distributed over {2} engines 
    = {3:.3f} sec  =  {4:0>2.0f}:{5:0>2.0f}:{6:0>2.0f} (h:m:s) \
'''.format(Nsims, atomTimeSec, Ncluster, estRunTimeSec, h, m, s))
estRunTimeSec = atomTimeSec*Nsims/4
m, s = divmod(estRunTimeSec, 60)
h, m = divmod(m, 60)
print('''\
* Virtual cores may not speed up computation!
    Assuming 3.5 \'real\' cores
    = {3:.3f} sec  =  {4:0>2.0f}:{5:0>2.0f}:{6:0>2.0f} (h:m:s)
'''.format(Nsims, atomTimeSec, Ncluster, estRunTimeSec, h, m, s))
# Out:
# Test algorithm
# ==============
# * timing 15 computations
#   (2017-03-02 20:24:21) ...  done (2017-03-02 20:24:21)
#     - time elapsed          =  3.60365e-02 sec
#     - time per computation  =  2.40243e-03 sec
# * using params
#     [   5, 778.0,
#         1.472,
#         130.0,
#         1, 6.6  ]
# * returns
#     [   778.0,
#         1.472,
#         130.0,
#         1, 6.6,
#         1.36475e+03,
#         2.97569e+00, 1.34994e+03,
#         8.88388e+02, 8.75843e+02  ]
# * Estimated run time
#     151452 computations
#       @ 2.40243e-03 sec/comp
#       distributed over 7 engines
#     = 51.979 sec  =  00:00:52 (h:m:s)
# * Virtual cores may not speed up computation!
#     Assuming 3.5 'real' cores
#     = 90.963 sec  =  00:01:31 (h:m:s)

# %% [markdown]
# #### Run full computation

# %%
print("Compute over all parameters")
print("===========================")

# Loop over parameters
print('* Computing ({:%Y-%m-%d %H:%M:%S}) ... '.format(datetime.datetime.now()), end='')
startSec = time.time()

calcMapList = list(cluster.map_sync(calcAtom, paramArray))

endSec = time.time()
print('done ({:%Y-%m-%d %H:%M:%S})'.format(datetime.datetime.now()))
dtSec = endSec - startSec
m, s = divmod(dtSec, 60)
h, m = divmod(m, 60)

calcMapArray = np.asarray(calcMapList)
Ncalcs = calcMapArray.shape[0]

mieCextCoreShellArray = calcMapArray

print('''\
    - Run time = {0:.3f} sec  =  {4:0>2.0f}:{5:0>2.0f}:{6:0>2.2f} (h:m:s)
    - Time per simulation instance = {1:.3e} sec
* Return variable
    - \"mieCextCoreShellArray\" = Mie theory calculated extinction spectrum
    - type:\t{2}
    - size:\t{3}
'''.format(dtSec, dtSec*Ncluster/Ncalcs, 
           type(mieCextCoreShellArray), 
           np.shape(np.asarray(mieCextCoreShellArray)),
           h, m, s
          )
     )
# Out:
# Compute over all parameters
# ===========================
# * Computing (2017-03-02 20:24:21) ... done (2017-03-02 20:25:39)
#     - Run time = 77.814 sec  =  00:01:17.81 (h:m:s)
#     - Time per simulation instance = 3.597e-03 sec
# * Return variable
#     - "mieCextCoreShellArray" = Mie theory calculated extinction spectrum
#     - type:	<class 'numpy.ndarray'>
#     - size:	(151452, 10)

# %% [markdown]
# #### Save results to file

# %%
print('''\
Save result to file  
=================== 
* Saving variable:\t\"mieCextCoreShellArray\" \
''')
timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.npy'
filename = ("npy/" + timestamp 
            + "_mie-Cext_core-shell_part0" 
            + exportFormat
            )
print('* To file:\t\t'+filename)
print('* Initiating ({:%Y-%m-%d %H:%M:%S}) ... '.format(datetime.datetime.now()), end='')
np.save(filename, mieCextCoreShellArray)
print('done ({:%Y-%m-%d %H:%M:%S})'.format(datetime.datetime.now()))
# Out:
# Save result to file
# ===================
# * Saving variable:	"mieCextCoreShellArray"
# * To file:		npy/20170302_mie-Cext_core-shell_part0.npy
# * Initiating (2017-03-02 20:25:39) ... done (2017-03-02 20:25:39)

# %% [markdown]
# ## Differences between cross sections

# %% [markdown]
# ### Difference between core-shell and core + shell

# %%
pylab.cla()

dCextRel = 1 - (mieCextCoreShellArray[:,-4] + mieCextCoreShellArray[:,-3])/mieCextCoreShellArray[:,-5]
pylab.hist(dCextRel )
pylab.show()
print(np.sort(dCextRel)[[0,-1]])

for sampleNum in range(6):
    for rShellnm in rShellListnmBySample[sampleNum]:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        select = ((mieCextCoreShellArray[:,2] == rShellnm) & (mieCextCoreShellArray[:,3] == coreNum))
        subset = mieCextCoreShellArray[select]
        rCorenm = subset[0,4]
        label = str(sampleNum) + ', ' + str(rShellnm/rCorenm)
        dCextRel = 1 - (subset[:,-4] + subset[:,-3])/subset[:,-5]
        pylab.semilogx(subset[:,2]/subset[:,4], dCextRel, '.', label=label)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
pylab.show()
# Out:
# [-0.168  0.128]

# %% [markdown]
# ### Difference between shell and swollen shell

# %%
pylab.cla()

select = (mieCextCoreShellArray[:,-3] > 0)
subset = mieCextCoreShellArray[select]

dCextRel = (subset[:,-1] - subset[:,-3])/(subset[:,-3])
print(np.sort(dCextRel)[[0,-1]])
pylab.hist(dCextRel )
pylab.show()

for sampleNum in range(6):
    for rShellnm in rShellListnmBySample[sampleNum]:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        select = ((mieCextCoreShellArray[:,2] == rShellnm) 
                  & (mieCextCoreShellArray[:,3] == coreNum)
                  & (mieCextCoreShellArray[:,-3] > 0))
        subset = mieCextCoreShellArray[select]
        rCorenm = subset[0,4]
        label = str(sampleNum) + ', ' + str(rShellnm/rCorenm)
        dCextRel = (subset[:,-1] - subset[:,-3])/(subset[:,-3])
        pylab.semilogx(subset[:,2]/subset[:,4], dCextRel, '.', label=label)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
pylab.show()

for sampleNum in range(6):
    for rShellnm in rShellListnmBySample[sampleNum]:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        select = ((mieCextCoreShellArray[:,2] == rShellnm) 
                  & (mieCextCoreShellArray[:,3] == coreNum)
                  & (mieCextCoreShellArray[:,-3] > 0))
        subset = mieCextCoreShellArray[select]
        rCorenm = subset[0,4]
        label = str(sampleNum) + ', ' + str(rShellnm/rCorenm)
        dCextRel = (subset[:,-1] - subset[:,-3])/(subset[:,-3])
        pylab.plot(subset[:,0], dCextRel, '.', label=label)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
pylab.show()
# Out:
# [-0.407 -0.22 ]

# %% [markdown]
# ### Difference between core-shell and swollen core-shell

# %%
pylab.cla()

select = (mieCextCoreShellArray[:,-2] > 0)
subset = mieCextCoreShellArray[select]

dCextRel = (subset[:,-2] - subset[:,-5])/(subset[:,-2])
print(np.sort(dCextRel)[[0,-1]])
pylab.hist(dCextRel )
pylab.show()

for sampleNum in range(6):
    for rShellnm in rShellListnmBySample[sampleNum]:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        select = ((mieCextCoreShellArray[:,2] == rShellnm) 
                  & (mieCextCoreShellArray[:,3] == coreNum)
                  & (mieCextCoreShellArray[:,-2] > 0))
        subset = mieCextCoreShellArray[select]
        rCorenm = subset[0,4]
        label = str(sampleNum) + ', ' + str(rShellnm/rCorenm)
        dCextRel = (subset[:,-2] - subset[:,-5])/(subset[:,-2])
        pylab.semilogx(subset[:,2]/subset[:,4], dCextRel, '.', label=label)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
pylab.show()

for sampleNum in range(6):
    for rShellnm in rShellListnmBySample[sampleNum]:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        select = ((mieCextCoreShellArray[:,2] == rShellnm) 
                  & (mieCextCoreShellArray[:,3] == coreNum)
                  & (mieCextCoreShellArray[:,-2] > 0))
        subset = mieCextCoreShellArray[select]
        rCorenm = subset[0,4]
        label = str(sampleNum) + ', ' + str(rShellnm/rCorenm)
        dCextRel = (subset[:,-2] - subset[:,-5])/(subset[:,-2])
        pylab.plot(subset[:,0], dCextRel, '.', label=label)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
pylab.show()
# Out:
# [ -6.182e-01   2.199e-14]

# %% [markdown]
# # Peak Analysis: Power law baseline for scattering correction

# %% [markdown]
# ## Peak analysis

# %% [markdown]
# ### Core spectrum analysis (in water)

# %% [markdown]
# #### Core spectrum without power law baseline

# %%
threshold = 0.25
wlExpectednm = 535
dwlExpectednm = 13
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier = "_lspr-core-peaks"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'Rcore-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Bare cores only')
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('  * peaks detected: \n    wl-nm (interp),\t [wl-nm,  ext]')

lsprMiePeakWLnmCoreList = []
for coreNum in range(2):
    nShell = nShellList[0]
    rShellnm = rShellListnmBySample[0][0]
    if coreNum > 0: rShellnm = rShellListnmBySample[3][0]
    rCorenm = rCoreListnm[coreNum]
    sampleType = (['L0-Core_D=','X0-Core_D='][coreNum]) + str(rCorenm) + '-nm'
    print('   - Core #',coreNum,'(',
          sampleType,
          ')')
    
    subdataArray = mieCextCoreShellArray
    selection = (
        (subdataArray[:,0] >= wlMin0nm) 
        & (subdataArray[:,0] <= wlMax0nm) 
        & (subdataArray[:,1] == nShell)
        & (subdataArray[:,2] == rShellnm)
        & (subdataArray[:,3] == coreNum)
    )
    subdataArray = subdataArray[selection]
    sort = np.argsort(subdataArray[:,0])
    subdataArray = subdataArray[sort]
    minDist = int(subdataArray[:,0].size/(nPeaks+1))
    
    x, y = subdataArray[:,0], subdataArray[:,-4]
    pylab.plot(x,y,'.')
    indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
    xPeaks = x[indexes]
    pylab.plot(x[indexes],y[indexes],'o')
    anArray = (np.array([xPeaks, indexes])).T
    select = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
    indexes = (anArray[select][:,1]).tolist()
    xPeaks = x[indexes]
    if (len(indexes) > 0): 
        result = [x[indexes[0]], y[indexes[0]]]
        xPeaks = peakutils.interpolate(x, y, ind=indexes)
        print('   ', ( round(100*xPeaks[0])/100 ),',\t\t',  
              np.round(100*np.array(result))/100 )
        result = [xPeaks[0], coreRnms[coreNum]]
        lsprMiePeakWLnmCoreList.append(result)

pylab.show()
filename = folder + timestamp + identifier + exportFormat
#np.savetxt(filename, lsprPeakWLnmCoreList, delimiter='\t', header=datHeader, fmt='%.2f')
#print('     + saved to', filename) 

print("  * output array format: \n    [ peak-wl-nm, Rcore-nm]")
# Out:
# LSPR peak wavelengths
# =====================
# Bare cores only
#   * looking for one peak at 535 nm
#     - in the range [ 522 , 548 ] nm
#   * peaks detected:
#     wl-nm (interp),	 [wl-nm,  ext]
#    - Core # 0 ( L0-Core_D=8.5-nm )
#     523.32 ,		 [ 523.    221.23]
#    - Core # 1 ( X0-Core_D=6.6-nm )
#     523.04 ,		 [ 523.     97.77]
#   * output array format:
#     [ peak-wl-nm, Rcore-nm]

# %% [markdown]
# #### Power law baseline of core spectrum, for later correction

# %%
threshold = 0.25
wlExpectednm = 535
dwlExpectednm = 13
wlScatnm = 400
x0base = wlExpectednm
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier = "_mie_lspr-core-peaks_baseline-powr"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'wl-orig-nm', 'Rcore-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Bare cores only')
print('  * power law baseline fit')
print('    - of the form ybase = k*(x/x0)^n')
print('    - using log-log/linear fitting with x0 =',x0base)
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('    - baseline correction range [', wlMin0nm, ',', wlMax0nm, '] nm')
print('Peaks detected: \n    wl-nm (interp),\t [wl-nm, ext], \t (orig wl-nm),\t gamma-Ref')

lsprMiePowrPeakWLnmCoreList = []
lsprMiePowrBaselineCoreList = []
lsprMiePowrBaselineCorenkList = []

for coreNum in range(2):
    nShell = nShellList[0]
    rShellnm = rShellListnmBySample[0][0]
    if coreNum > 0: rShellnm = rShellListnmBySample[3][0]
    rCorenm = rCoreListnm[coreNum]
    sampleType = (['L0-Core_D=','X0-Core_D='][coreNum]) + str(int(round(2*coreRnms[coreNum]))) + '-nm'
    print('  * Core #',coreNum,'(', sampleType, ')', end="")
    
    subdataArray = mieCextCoreShellArray
    selection = (
        (subdataArray[:,0] >= wlMin0nm) 
        & (subdataArray[:,0] <= wlMax0nm) 
        & (subdataArray[:,1] == nShell)
        & (subdataArray[:,2] == rShellnm)
        & (subdataArray[:,3] == coreNum)
    )
    subdataArray = subdataArray[selection]
    sort = np.argsort(subdataArray[:,0])
    subdataArray = subdataArray[sort]
    minDist = int(subdataArray[:,0].size/(nPeaks+1))
    
    x, y = subdataArray[:,0], subdataArray[:,-4]
    yOrig = y
    logx, logy = np.log(x/x0base), np.log(y)
    dlogx = min(np.abs(np.diff(logx)))
    loglogx = np.arange(min(logx), max(logx) + 0.5*dlogx, dlogx)
    loglogy = np.interp(loglogx, logx, logy)
    
    loglogyLinBase = peakutils.baseline(loglogy, 1)
    logyLinBase = np.interp(logx, loglogx, loglogyLinBase)
    loglogfit = np.polyfit(logx, logyLinBase, 1)
    basePowrn, baseCoeffk = loglogfit[0], np.exp(loglogfit[1])
    print('\t{baseline n =', '{0:.2f}'.format(basePowrn),', k =', '{0:.1f}'.format(baseCoeffk),'}')
    
    yPowrBase = (np.exp(logyLinBase))
    y = y - yPowrBase
    pylab.plot(x,yOrig,'.')
    pylab.plot(x,y,'.')
    
    indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
    xPeaks = x[indexes]
    anArray = (np.array([xPeaks, indexes])).T
    selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
    indexes = (anArray[selection][:,1]).tolist()
    xPeaks = x[indexes]
    if (len(indexes) > 0): 
        result = [ x[indexes[0]], y[indexes[0]] ]
        pylab.plot(x[indexes],yOrig[indexes],'o')
        pylab.plot(x[indexes],y[indexes],'o')
        xPeaks = peakutils.interpolate(x, y, ind=indexes)
        
        xPeak = xPeaks[0]
        select = (np.abs(x-xPeak) < 0.55)
        subdataArrayPeak = yOrig[select][0]
        select = (np.abs(x-wlScatnm) < 0.55)
        subdataArrayScat = yOrig[select][0]
        gammaCoreRef = subdataArrayPeak/subdataArrayScat
        
        print('   ', round(100*xPeak)/100,',\t\t',  
              np.round(100*np.array(result))/100,
              '\t (', round(100*lsprMiePeakWLnmCoreList[coreNum][0])/100,')',
              ',\t ', gammaCoreRef
              )
        
        result = [xPeak, lsprPeakWLnmCoreList[coreNum][0], coreRnms[coreNum], gammaCoreRef]
        
        lsprMiePowrPeakWLnmCoreList.append(result)
        lsprMiePowrBaselineCoreList.append([x, yOrig, y[indexes][0], y, yPowrBase])
        lsprMiePowrBaselineCorenkList.append([x0base, basePowrn, baseCoeffk])

pylab.show()
filename = folder + timestamp + identifier + exportFormat
#np.savetxt(filename, lsprPowrPeakWLnmCoreList, delimiter='\t', header=datHeader, fmt='%.2f')
#print('     + saved to', filename) 
print('variable: \t lsprMiePowrPeakWLnmCoreList')
print("  * output array format: \n    [ peak-wl-nm, orig-peak-wl-nm, Rcore-nm, gamma-Ref ]")
print('variable: \t lsprMiePowrBaselineCoreList')
print("  * output array format: \n    [ wl-nm-data, ext-data, peak-corr-ext",
      "ext-corrected-data, baseline-correction-data]")
print('  * wavelength range: [',lsprMiePowrBaselineCoreList[0][0][0],',', 
      lsprMiePowrBaselineCoreList[0][0][-1],'] x (',len(lsprMiePowrBaselineCoreList[0][0]), 'values)')
print('variable: \t lsprMiePowrBaselineCorenkList')
print("  * output array format: \n    [ x0, n, k ]")
# Out:
# LSPR peak wavelengths
# =====================
# Bare cores only
#   * power law baseline fit
#     - of the form ybase = k*(x/x0)^n
#     - using log-log/linear fitting with x0 = 535
#   * looking for one peak at 535 nm
#     - in the range [ 522 , 548 ] nm
#     - baseline correction range [ 400 , 800 ] nm
# Peaks detected:
#     wl-nm (interp),	 [wl-nm, ext], 	 (orig wl-nm),	 gamma-Ref
#   * Core # 0 ( L0-Core_D=17-nm )	{baseline n = -5.57 , k = 30.0 }
#     524.34 ,		 [ 524.    187.45] 	 ( 523.32 ) ,	  1.60035963976
#   * Core # 1 ( X0-Core_D=13-nm )	{baseline n = -5.33 , k = 14.6 }
#     524.2 ,		 [ 524.     81.36] 	 ( 523.04 ) ,	  1.54343801594
# variable: 	 lsprMiePowrPeakWLnmCoreList
#   * output array format:
#     [ peak-wl-nm, orig-peak-wl-nm, Rcore-nm, gamma-Ref ]
# variable: 	 lsprMiePowrBaselineCoreList
#   * output array format:
#     [ wl-nm-data, ext-data, peak-corr-ext ext-corrected-data, baseline-correction-data]
#   * wavelength range: [ 400.0 , 800.0 ] x ( 401 values)
# variable: 	 lsprMiePowrBaselineCorenkList
#   * output array format:
#     [ x0, n, k ]

# %% [markdown]
# ### Core-shell spectrum analysis

# %% [markdown]
# #### Hard sphere

# %%
threshold = .25
wlExpectednm = 535
dwlExpectednm = 13
wlScatnm = 400
x0base = wlExpectednm
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier0 = "lspr-peaks_baseline-powr"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'orig-wl-nm', 'temp-C', 'Rh-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Core-shell nanoparticles')
print('  * power law baseline fit')
print('    - of the form ybase = k*(x/x0)^n')
print('    - using log-log/linear fitting with x0 =',x0base)
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('    - baseline correction range [', wlMin0nm, ',', wlMax0nm, '] nm')
print('Peaks detected: \n    wl-nm,\t [wl-nm, ext, rShell-nm, nShell]',
     '\t (n0, k0)', '\t scal.',  '\t (n, k)', '\t gamma')

lsprMiePowrPeakWLnmList = []
lsprMiePowrBaselineList = []
lsprMiePowrBaselinenkList = []
x = []

for sampleNum in range(6):
    sampleType = (['L1-Thn','L2-Med','L3-Thk','X1-Thn','X2-Med','X3-Thk'][sampleNum])
    print(' * Sample #',sampleNum,'(', sampleType, ')')
    lsprPeakWLnmSubList = []
    coreNum = 0
    if sampleNum > 2: coreNum = 1
    gammaCoreRef = lsprMiePowrPeakWLnmCoreList[coreNum][-1]
    
    for nShell in nShellList:
        for rShellnm in rShellListnmBySample[sampleNum]:
            xPeakPrev = wlExpectednm
            if len(lsprPeakWLnmSubList) > 0: xPeakPrev = lsprPeakWLnmSubList[-1][0]
            subdataArray = mieCextCoreShellArray
            selection = (
                (subdataArray[:,0] >= wlMin0nm) 
                & (subdataArray[:,0] <= wlMax0nm) 
                & (subdataArray[:,1] == nShell)
                & (subdataArray[:,2] == rShellnm)
                & (subdataArray[:,3] == coreNum)
            )
            subdataArray = subdataArray[selection]
            sort = np.argsort(subdataArray[:,0])
            subdataArray = subdataArray[sort]
            minDist = int(subdataArray[:,0].size/(nPeaks+1))

            x, y = subdataArray[:,0], subdataArray[:,-5]
            yOrig = y
            logx, logy = np.log(x/x0base), np.log(y)
            dlogx = min(np.abs(np.diff(logx)))
            loglogx = np.arange(min(logx), max(logx) + dlogx, dlogx)
            logy0base = 1.01*min(logy)
            loglogy = np.interp(loglogx, logx, logy - logy0base)

            loglogyLinBase = peakutils.baseline(loglogy, 1)
            logyLinBase = np.interp(logx, loglogx, loglogyLinBase) + logy0base
            loglogfit = np.polyfit(logx, logyLinBase, 1)
            basePowrn0, baseCoeffk0 = loglogfit[0], np.exp(loglogfit[1])

            yPowrBase = (np.exp(logyLinBase))
            y = y - yPowrBase
            indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
            xPeaks = x[indexes]
            anArray = (np.array([xPeaks, indexes])).T
            selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
            indexes = anArray[selection][:,1].astype(int)
            # if no peaks:
            if (len(indexes) == 0): 
                selection = (x >= wlMinnm) & (x <= wlMaxnm)
                xzoom, yzoom = x[selection], y[selection]
                indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                indexes = indexeszoom + int(wlMinnm - wlMin0nm)
                if (len(indexes) == 0): 
                    indexes = np.argsort(np.abs(x - xPeakPrev))[[0]]
            xPeaks = x[indexes]

            selection = ( (lsprMiePowrBaselineCoreList[coreNum][0] >= wlMin0nm)
                         & (lsprMiePowrBaselineCoreList[coreNum][0] <= wlMax0nm)
                         )
            yCorePowrBase = np.asarray(lsprMiePowrBaselineCoreList[coreNum][-1])[selection]
            yCorePeak = lsprMiePowrBaselineCoreList[coreNum][2]
            scaling = 1*y[indexes][0]/yCorePeak
            y = y + yCorePowrBase*scaling

            # fit [(base) - (core base)] to power law
            yPowrBaseTotal = yPowrBase - yCorePowrBase*scaling
            logy = np.log(yPowrBaseTotal)
            if min(yPowrBaseTotal) > 0: 
                logy = np.log(yPowrBaseTotal)
                loglogfit = np.polyfit(logx, logy, 1)
            else: loglogfit = [0, 0]
            basePowrn, baseCoeffk = loglogfit[0], np.exp(loglogfit[1])

            indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
            xPeaks = x[indexes]
            anArray = (np.array([xPeaks, indexes])).T
            selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
            indexes = anArray[selection][:,1].astype(int)
            # if no peaks:
            if (len(indexes) == 0): 
                selection = (x >= wlMinnm) & (x <= wlMaxnm)
                xzoom, yzoom = x[selection], y[selection]
                indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                indexes = indexeszoom + int(wlMinnm - wlMin0nm)
                if (len(indexes) == 0): 
                    indexes = np.argsort(np.abs(x - xPeakPrev))[[0]]
            xPeaks = x[indexes]

            # iterate 
            for i in range(5):
                oldScaling = scaling
                scaling = 1*(y[indexes[0]] - yCorePowrBase[indexes[0]]*scaling)/yCorePeak
                if ( abs(1-oldScaling/scaling) < 0.001 ): break

                y = yOrig - yPowrBase + yCorePowrBase*scaling
                indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
                xPeaks = x[indexes]
                anArray = (np.array([xPeaks, indexes])).T
                selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
                indexes = anArray[selection][:,1].astype(int)
                # if no peaks:
                if (len(indexes) == 0): 
                    selection = (x >= wlMinnm) & (x <= wlMaxnm)
                    xzoom, yzoom = x[selection], y[selection]
                    indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                    indexes = indexeszoom + (wlMinnm - wlMin0nm)
                if (len(indexes) == 0): break
            
            if (len(indexes) > 0): 
                result = np.array([ x[indexes[0]], y[indexes[0]], rShellnm, nShell ])
                xPeaks = peakutils.interpolate(x, y, ind=indexes)
                
                xPeak = xPeaks[0]
                select = (np.abs(x-xPeak) < 0.55)
                subdataArrayPeak = yOrig[select][0]
                select = (np.abs(x-wlScatnm) < 0.55)
                subdataArrayScat = yOrig[select][0]
                gamma = (subdataArrayPeak/subdataArrayScat)/gammaCoreRef

                print('   ', round(100*xPeak)/100,',\t',  
                      (np.round(100*result[:])/100).tolist(),
                      '\t ({0:.2f}, {1:.3f})\t {2:.3f}'.format(basePowrn0, baseCoeffk0, scaling),
                      '\t ({0:.2f}, {1:.2f})'.format(basePowrn, baseCoeffk),
                      '\t {0:.3f}'.format(gamma)
                     )
                
                select = (np.abs(x-xPeak) < 0.55)
                scalingErrMeasure = np.abs(yPowrBase[select]/yCorePowrBase[select])[0]
                # problems with large scattering cross sections
                if (baseCoeffk0 > 1e3): 
                    print('\t* Warning *: large scattering cross section' )
                    pylab.cla()
                    pylab.plot(x,yOrig,'-')
                    pylab.plot(x,yPowrBase,':')
                    pylab.plot(x,yPowrBase-yCorePowrBase*scaling,'--')
                    pylab.plot(x,y,'-')
                    pylab.show()
                
                result = [xPeak, gamma, rShellnm, nShell, sampleNum]
                lsprMiePowrPeakWLnmList.append(result)
                lsprMiePowrBaselineList.append([x, yOrig, scaling, y, yPowrBase, 
                                             yPowrBase-yCorePowrBase*scaling])
                lsprMiePowrBaselinenkList.append([x0base, basePowrn0, baseCoeffk0])
                result = [xPeaks[0], result[-3], result[-2]]
                lsprPeakWLnmSubList.append(result)
            
            else: # if no peaks detected
                print('\t* Error *: no peaks detected in range', (rShellnm, nShell) )
                pylab.cla()
                pylab.plot(x,yOrig,'-')
                pylab.plot(x,yPowrBase,':')
                pylab.plot(x,yPowrBase-yCorePowrBase*scaling,'--')
                pylab.plot(x,y,'-')
                pylab.show()
            
    if len(lsprPeakWLnmSubList) == 0: lsprPeakWLnmSubList.append( [0,0,0] )
    lsprPeakWLnmSubList = np.asarray(lsprPeakWLnmSubList)
    identifier = '_' + identifier0 + '_' + str(sampleNum) + '-' + sampleType
    filename = folder + timestamp + identifier + exportFormat
    #np.savetxt(filename, lsprPeakWLnmSubList, delimiter='\t', header=datHeader, fmt='%.2f')
    #print('      + saved to', filename) 

lsprMiePowrPeakWLnmArray = np.asarray(lsprMiePowrPeakWLnmList)
print('variable: \t lsprMiePowrPeakWLnmArray')
print("  * output array format: \n    [ peak-wl-nm, gamma, rShell-nm, nShell, sample-# ]")
print("    - sample-# = [0,...,5] \n      for [L1-Thin, L2-Med., L3-Thik, X1-Thin, X2-Med., X3-Thick]")
print('variable: \t lsprMiePowrBaselineList')
print("  * output array format: \n",
      "   [ wl-nm-data, ext-orig-data, ext-scaling-factor, ext-corrected-data,",
      "baseline-correction-no-core-data, baseline-correction-data]")
print('  * wavelength range: [',x[0],',',x[-1],'] x (',len(x), 'values)')
print('variable: \t lsprMiePowrBaselinenkList')
print("  * output array format: \n    [ x0, n0, k0 ]")
# Out:
# LSPR peak wavelengths
# =====================
# Core-shell nanoparticles
#   * power law baseline fit
#     - of the form ybase = k*(x/x0)^n
#     - using log-log/linear fitting with x0 = 535
#   * looking for one peak at 535 nm
#     - in the range [ 522 , 548 ] nm
# 	* Warning *: large scattering cross section
#     532.24 ,	 [532.0, 262.06, 140.0, 1.45] 	 (-2.14, 3154.321)	 2.717 	 (-2.11, 3107.36) 	 0.386
# 	* Warning *: large scattering cross section
# 	* Error *: no peaks detected in range (160.0, 1.4521058963738434)
# 	* Error *: no peaks detected in range (180.0, 1.4521058963738434)
#     533.0 ,	 [533.0, 261.1, 100.0, 1.47] 	 (-2.64, 1021.927)	 2.712 	 (-2.54, 977.06) 	 0.379
# 	* Warning *: large scattering cross section
#     536.39 ,	 [536.0, 269.79, 120.0, 1.47] 	 (-2.35, 2277.627)	 2.815 	 (-2.30, 2229.92) 	 0.366
# 	* Warning *: large scattering cross section
#     532.2 ,	 [532.0, 322.54, 140.0, 1.47] 	 (-2.14, 4311.282)	 3.345 	 (-2.11, 4253.47) 	 0.384
# 	* Warning *: large scattering cross section
#     513.8 ,	 [532.0, 940.16, 160.0, 1.47] 	 (-1.90, 7036.140)	 9.749 	 (-1.84, 6863.60) 	 0.458
# 	* Warning *: large scattering cross section
# 	* Error *: no peaks detected in range (180.0, 1.4721058963738434)
#     534.55 ,	 [534.0, 302.61, 100.0, 1.49] 	 (-2.64, 1331.911)	 3.148 	 (-2.55, 1279.75) 	 0.369
# 	* Warning *: large scattering cross section
#     538.97 ,	 [539.0, 296.11, 120.0, 1.49] 	 (-2.35, 2995.625)	 3.103 	 (-2.31, 2943.12) 	 0.356
# 	* Warning *: large scattering cross section
#     530.47 ,	 [531.0, 414.87, 140.0, 1.49] 	 (-2.14, 5644.788)	 4.295 	 (-2.11, 5570.52) 	 0.387
# 	* Warning *: large scattering cross section
#     506.42 ,	 [530.0, 1342.22, 160.0, 1.49] 	 (-1.89, 9182.795)	 13.874 	 (-1.82, 8936.81) 	 0.477
# 	* Warning *: large scattering cross section
# 	* Error *: no peaks detected in range (180.0, 1.4921058963738434)
# variable: 	 lsprMiePowrPeakWLnmArray
#   * output array format:
#     [ peak-wl-nm, gamma, rShell-nm, nShell, sample-# ]
#     - sample-# = [0,...,5]
#       for [L1-Thin, L2-Med., L3-Thik, X1-Thin, X2-Med., X3-Thick]
# variable: 	 lsprMiePowrBaselineList
#   * output array format:
#     [ wl-nm-data, ext-orig-data, ext-scaling-factor, ext-corrected-data, baseline-correction-no-core-data, baseline-correction-data]
#   * wavelength range: [ 400.0 , 800.0 ] x ( 401 values)
# variable: 	 lsprMiePowrBaselinenkList
#   * output array format:
#     [ x0, n0, k0 ]

# %% [markdown]
# #### Soft sphere

# %%
threshold = .25
wlExpectednm = 535
dwlExpectednm = 13
wlScatnm = 400
x0base = wlExpectednm
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier0 = "lspr-peaks_baseline-powr"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'orig-wl-nm', 'temp-C', 'Rh-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Core-shell (soft) nanoparticles')
print('  * power law baseline fit')
print('    - of the form ybase = k*(x/x0)^n')
print('    - using log-log/linear fitting with x0 =',x0base)
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('    - baseline correction range [', wlMin0nm, ',', wlMax0nm, '] nm')
print('Peaks detected: \n    wl-nm,\t [wl-nm, ext, rShell-nm, nShell]',
     '\t (n0, k0)', '\t scal.',  '\t (n, k)', '\t gamma')

lsprMieSoftPowrPeakWLnmList = []
lsprMieSoftPowrBaselineList = []
lsprMieSoftPowrBaselinenkList = []
x = []

for sampleNum in range(6):
    sampleType = (['L1-Thn','L2-Med','L3-Thk','X1-Thn','X2-Med','X3-Thk'][sampleNum])
    print(' * Sample #',sampleNum,'(', sampleType, ')')
    lsprPeakWLnmSubList = []
    coreNum = 0
    if sampleNum > 2: coreNum = 1
    gammaCoreRef = lsprMiePowrPeakWLnmCoreList[coreNum][-1]
    
    for nShell in nShellList:
        for rShellnm in rShellListnmBySample[sampleNum]:
            xPeakPrev = wlExpectednm
            if len(lsprPeakWLnmSubList) > 0: xPeakPrev = lsprPeakWLnmSubList[-1][0]
            subdataArray = mieCextCoreShellArray
            selection = (
                (subdataArray[:,0] >= wlMin0nm) 
                & (subdataArray[:,0] <= wlMax0nm) 
                & (subdataArray[:,1] == nShell)
                & (subdataArray[:,2] == rShellnm)
                & (subdataArray[:,3] == coreNum)
            )
            subdataArray = subdataArray[selection]
            sort = np.argsort(subdataArray[:,0])
            subdataArray = subdataArray[sort]
            minDist = int(subdataArray[:,0].size/(nPeaks+1))

            x, y = subdataArray[:,0], subdataArray[:,-2]
            yOrig = y
            yHard = subdataArray[:,-5]
            logx, logy = np.log(x/x0base), np.log(y)
            dlogx = min(np.abs(np.diff(logx)))
            loglogx = np.arange(min(logx), max(logx) + dlogx, dlogx)
            logy0base = 1.01*min(logy)
            loglogy = np.interp(loglogx, logx, logy - logy0base)

            loglogyLinBase = peakutils.baseline(loglogy, 1)
            logyLinBase = np.interp(logx, loglogx, loglogyLinBase) + logy0base
            loglogfit = np.polyfit(logx, logyLinBase, 1)
            basePowrn0, baseCoeffk0 = loglogfit[0], np.exp(loglogfit[1])

            yPowrBase = (np.exp(logyLinBase))
            y = y - yPowrBase
            indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
            xPeaks = x[indexes]
            anArray = (np.array([xPeaks, indexes])).T
            selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
            indexes = anArray[selection][:,1].astype(int)
            # if no peaks:
            if (len(indexes) == 0): 
                selection = (x >= wlMinnm) & (x <= wlMaxnm)
                xzoom, yzoom = x[selection], y[selection]
                indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                indexes = indexeszoom + int(wlMinnm - wlMin0nm)
                if (len(indexes) == 0): 
                    indexes = np.argsort(np.abs(x - xPeakPrev))[[0]]
            xPeaks = x[indexes]

            selection = ( (lsprMiePowrBaselineCoreList[coreNum][0] >= wlMin0nm)
                         & (lsprMiePowrBaselineCoreList[coreNum][0] <= wlMax0nm)
                         )
            yCorePowrBase = np.asarray(lsprMiePowrBaselineCoreList[coreNum][-1])[selection]
            yCorePeak = lsprMiePowrBaselineCoreList[coreNum][2]
            scaling = 1*y[indexes][0]/yCorePeak
            y = y + yCorePowrBase*scaling

            # fit [(base) - (core base)] to power law
            yPowrBaseTotal = yPowrBase - yCorePowrBase*scaling
            logy = np.log(yPowrBaseTotal)
            if min(yPowrBaseTotal) > 0: 
                logy = np.log(yPowrBaseTotal)
                loglogfit = np.polyfit(logx, logy, 1)
            else: loglogfit = [0, 0]
            basePowrn, baseCoeffk = loglogfit[0], np.exp(loglogfit[1])

            indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
            xPeaks = x[indexes]
            anArray = (np.array([xPeaks, indexes])).T
            selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
            indexes = anArray[selection][:,1].astype(int)
            # if no peaks:
            if (len(indexes) == 0): 
                selection = (x >= wlMinnm) & (x <= wlMaxnm)
                xzoom, yzoom = x[selection], y[selection]
                indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                indexes = indexeszoom + int(wlMinnm - wlMin0nm)
                if (len(indexes) == 0): 
                    indexes = np.argsort(np.abs(x - xPeakPrev))[[0]]
            xPeaks = x[indexes]

            # iterate 
            for i in range(5):
                oldScaling = scaling
                scaling = 1*(y[indexes[0]] - yCorePowrBase[indexes[0]]*scaling)/yCorePeak
                if ( abs(1-oldScaling/scaling) < 0.001 ): break

                y = yOrig - yPowrBase + yCorePowrBase*scaling
                indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
                xPeaks = x[indexes]
                anArray = (np.array([xPeaks, indexes])).T
                selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
                indexes = anArray[selection][:,1].astype(int)
                # if no peaks:
                if (len(indexes) == 0): 
                    selection = (x >= wlMinnm) & (x <= wlMaxnm)
                    xzoom, yzoom = x[selection], y[selection]
                    indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                    indexes = indexeszoom + (wlMinnm - wlMin0nm)
                if (len(indexes) == 0): break
            
            if (len(indexes) > 0): 
                result = np.array([ x[indexes[0]], y[indexes[0]], rShellnm, nShell ])
                xPeaks = peakutils.interpolate(x, y, ind=indexes)
                
                xPeak = xPeaks[0]
                select = (np.abs(x-xPeak) < 0.55)
                subdataArrayPeak = yOrig[select][0]
                select = (np.abs(x-wlScatnm) < 0.55)
                subdataArrayScat = yOrig[select][0]
                gamma = (subdataArrayPeak/subdataArrayScat)/gammaCoreRef
                

                print('   ', round(100*xPeak)/100,',\t',  
                      (np.round(100*result[:])/100).tolist(),
                      '\t ({0:.2f}, {1:.3f})\t {2:.3f}'.format(basePowrn0, baseCoeffk0, scaling),
                      '\t ({0:.2f}, {1:.2f})'.format(basePowrn, baseCoeffk),
                      '\t {0:.3f}'.format(gamma)
                     )
                
                # problems when shell is big, due to Mie resonances, etc
                if (baseCoeffk0 > 1000): 
                    print('\t* Warning *: large scattering coefficient')
                    pylab.cla()
                    pylab.plot(x,yHard,'--')
                    pylab.plot(x,yOrig,'-')
                    pylab.plot(x,yPowrBase,':')
                    pylab.plot(x,yPowrBase-yCorePowrBase*scaling,'--')
                    pylab.plot(x,y,'-')
                    pylab.show()
                    
                result = [xPeak, gamma, rShellnm, nShell, sampleNum]
                lsprMieSoftPowrPeakWLnmList.append(result)
                lsprMieSoftPowrBaselineList.append([x, yOrig, scaling, y, yPowrBase, 
                                             yPowrBase-yCorePowrBase*scaling])
                lsprMieSoftPowrBaselinenkList.append([x0base, basePowrn0, baseCoeffk0])
                result = [xPeaks[0], result[-3], result[-2]]
                lsprPeakWLnmSubList.append(result)
                
            else: # no peaks found
                # problems when shell is big, due to Mie resonances, etc
                if (baseCoeffk0 > 1000): 
                    print('\t* Error *: no peaks found in range, ', (rShellnm, nShell))
                    pylab.cla()
                    pylab.plot(x,yHard,'--')
                    pylab.plot(x,yOrig,'-')
                    pylab.plot(x,yPowrBase,':')
                    pylab.plot(x,yPowrBase-yCorePowrBase*scaling,'--')
                    pylab.plot(x,y,'-')
                    pylab.show()
            
    if len(lsprPeakWLnmSubList) == 0: lsprPeakWLnmSubList.append( [0,0,0] )
    lsprPeakWLnmSubList = np.asarray(lsprPeakWLnmSubList)
    identifier = '_' + identifier0 + '_' + str(sampleNum) + '-' + sampleType
    filename = folder + timestamp + identifier + exportFormat
    #np.savetxt(filename, lsprPeakWLnmSubList, delimiter='\t', header=datHeader, fmt='%.2f')
    #print('      + saved to', filename) 

lsprMieSoftPowrPeakWLnmArray = np.asarray(lsprMieSoftPowrPeakWLnmList)
print('variable: \t lsprMieSoftPowrPeakWLnmArray')
print("  * output array format: \n    [ peak-wl-nm, gamma, rShell-nm, nShell, sample-# ]")
print("    - sample-# = [0,...,5] \n      for [L1-Thin, L2-Med., L3-Thik, X1-Thin, X2-Med., X3-Thick]")
print('variable: \t lsprMieSoftPowrBaselineList')
print("  * output array format: \n",
      "   [ wl-nm-data, ext-orig-data, ext-scaling-factor, ext-corrected-data,",
      "baseline-correction-no-core-data, baseline-correction-data]")
print('  * wavelength range: [',x[0],',',x[-1],'] x (',len(x), 'values)')
print('variable: \t lsprMieSoftPowrBaselinenkList')
print("  * output array format: \n    [ x0, n0, k0 ]")
# Out:
# LSPR peak wavelengths
# =====================
# Core-shell (soft) nanoparticles
#   * power law baseline fit
#     - of the form ybase = k*(x/x0)^n
#     - using log-log/linear fitting with x0 = 535
#   * looking for one peak at 535 nm
#     - in the range [ 522 , 548 ] nm
#     - baseline correction range [ 400 , 800 ] nm
# Peaks detected:
#     wl-nm,	 [wl-nm, ext, rShell-nm, nShell] 	 (n0, k0) 	 scal. 	 (n, k) 	 gamma
#  * Sample # 0 ( L1-Thn )
#     523.3 ,	 [523.0, 221.49, 16.0, 1.33] 	 (-5.55, 29.809)	 1.000 	 (0.00, 1.00) 	 1.000
# 	* Warning *: large scattering coefficient
# 	* Error *: no peaks found in range,  (180.0, 1.4521058963738434)
#     532.25 ,	 [532.0, 231.46, 100.0, 1.47] 	 (-2.80, 682.973)	 2.400 	 (-2.68, 643.71) 	 0.386
#     534.47 ,	 [534.0, 275.08, 120.0, 1.47] 	 (-2.46, 1524.780)	 2.861 	 (-2.38, 1476.67) 	 0.376
# 	* Warning *: large scattering coefficient
#     536.49 ,	 [536.0, 260.98, 140.0, 1.47] 	 (-2.24, 2957.885)	 2.723 	 (-2.20, 2911.27) 	 0.371
# 	* Warning *: large scattering coefficient
#     526.24 ,	 [527.0, 452.33, 160.0, 1.47] 	 (-2.04, 4995.070)	 4.653 	 (-2.00, 4913.70) 	 0.408
# 	* Warning *: large scattering coefficient
#     511.21 ,	 [526.0, 1122.87, 180.0, 1.47] 	 (-1.83, 7621.154)	 11.531 	 (-1.75, 7415.36) 	 0.474
# 	* Warning *: large scattering coefficient
#     533.61 ,	 [534.0, 266.27, 100.0, 1.49] 	 (-2.79, 887.095)	 2.769 	 (-2.68, 841.81) 	 0.375
#     536.44 ,	 [536.0, 317.45, 120.0, 1.49] 	 (-2.45, 1995.758)	 3.312 	 (-2.39, 1940.08) 	 0.367
# 	* Warning *: large scattering coefficient
#     538.48 ,	 [538.0, 295.82, 140.0, 1.49] 	 (-2.24, 3884.347)	 3.096 	 (-2.21, 3831.38) 	 0.364
# 	* Warning *: large scattering coefficient
# 	* Error *: no peaks found in range,  (160.0, 1.4921058963738434)
#     513.28 ,	 [538.0, 1483.07, 180.0, 1.49] 	 (-1.81, 9947.435)	 15.519 	 (-1.74, 9669.96) 	 0.477
# 	* Warning *: large scattering coefficient
# variable: 	 lsprMieSoftPowrPeakWLnmArray
#   * output array format:
#     [ peak-wl-nm, gamma, rShell-nm, nShell, sample-# ]
#     - sample-# = [0,...,5]
#       for [L1-Thin, L2-Med., L3-Thik, X1-Thin, X2-Med., X3-Thick]
# variable: 	 lsprMieSoftPowrBaselineList
#   * output array format:
#     [ wl-nm-data, ext-orig-data, ext-scaling-factor, ext-corrected-data, baseline-correction-no-core-data, baseline-correction-data]
#   * wavelength range: [ 400.0 , 800.0 ] x ( 401 values)
# variable: 	 lsprMieSoftPowrBaselinenkList
#   * output array format:
#     [ x0, n0, k0 ]

# %% [markdown]
# ### Core spectrum analysis, in shell-like medium

# %% [markdown]
# #### Core spectrum without power law baseline

# %%
threshold = .25
wlExpectednm = 535
dwlExpectednm = 13
wlScatnm = 400
x0base = wlExpectednm
nPeaks = 1
wlMin0nm, wlMax0nm = 400, 800
wlMinnm, wlMaxnm = wlExpectednm-dwlExpectednm, wlExpectednm+dwlExpectednm

timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.dat'
identifier0 = "lspr-peaks_baseline-powr"
folder = 'graphics/'
datHeader = ('\t').join(('wl-nm', 'orig-wl-nm', 'temp-C', 'Rh-nm'))

print('LSPR peak wavelengths')
print('=====================')
print('Core-shell nanoparticles')
print('  * looking for one peak at', wlExpectednm, 
      'nm \n    - in the range [', wlMinnm, ',', wlMaxnm, '] nm')
print('    - baseline correction range [', wlMin0nm, ',', wlMax0nm, '] nm')
print('Peaks detected: \n    wl-nm,\t [wl-nm, ext, nShell]',
      '\t gamma')

lsprMieCorePeakWLnmList = []
x = []

for sampleNum in range(6):
    sampleType = (['L1-Thn','L2-Med','L3-Thk','X1-Thn','X2-Med','X3-Thk'][sampleNum])
    print(' * Sample #',sampleNum,'(', sampleType, ')')
    lsprPeakWLnmSubList = []
    coreNum = 0
    if sampleNum > 2: coreNum = 1
    gammaCoreRef = lsprMiePowrPeakWLnmCoreList[coreNum][-1]
    
    for nShell in nShellList:
        for rShellnm in rShellListnmBySample[sampleNum][[0]]:
            xPeakPrev = wlExpectednm
            if len(lsprPeakWLnmSubList) > 0: xPeakPrev = lsprPeakWLnmSubList[-1][0]
            subdataArray = mieCextCoreShellArray
            selection = (
                (subdataArray[:,0] >= wlMin0nm) 
                & (subdataArray[:,0] <= wlMax0nm) 
                & (subdataArray[:,1] == nShell)
                & (subdataArray[:,2] == rShellnm)
                & (subdataArray[:,3] == coreNum)
            )
            subdataArray = subdataArray[selection]
            sort = np.argsort(subdataArray[:,0])
            subdataArray = subdataArray[sort]
            minDist = int(subdataArray[:,0].size/(nPeaks+1))

            x, y = subdataArray[:,0], subdataArray[:,-4]

            indexes = peakutils.indexes(y, thres=threshold, min_dist=minDist)
            xPeaks = x[indexes]
            anArray = (np.array([xPeaks, indexes])).T
            selection = (anArray[:,0] > wlMinnm) & (anArray[:,0] < wlMaxnm)
            indexes = anArray[selection][:,1].astype(int)
            # if no peaks:
            if (len(indexes) == 0): 
                selection = (x >= wlMinnm) & (x <= wlMaxnm)
                xzoom, yzoom = x[selection], y[selection]
                indexeszoom = peakutils.indexes(yzoom, thres=threshold, min_dist=minDist)
                indexes = indexeszoom + int(wlMinnm - wlMin0nm)
                if (len(indexes) == 0): 
                    indexes = np.argsort(np.abs(x - xPeakPrev))[[0]]
            xPeaks = x[indexes]
            
            if (len(indexes) > 0): 
                result = np.array([ x[indexes[0]], y[indexes[0]], nShell ])
                xPeaks = peakutils.interpolate(x, y, ind=indexes)
                
                xPeak = xPeaks[0]
                select = (np.abs(x-xPeak) < 0.55)
                subdataArrayPeak = y[select][0]
                select = (np.abs(x-wlScatnm) < 0.55)
                subdataArrayScat = y[select][0]
                gamma = (subdataArrayPeak/subdataArrayScat)/gammaCoreRef

                print('   ', round(100*xPeak)/100,',\t',  
                      (np.round(100*result[:])/100).tolist(),
                      '\t {0:.3f}'.format(gamma)
                     )
                                
                result = [xPeak, gamma, nShell, sampleNum]
                lsprMieCorePeakWLnmList.append(result)
                result = [xPeaks[0], result[-3], result[-2]]
                lsprPeakWLnmSubList.append(result)
            
            else: # if no peaks detected
                print('\t* Error *: no peaks detected in range', (rShellnm, nShell) )
                pylab.cla()
                pylab.plot(x,yOrig,'-')
                pylab.plot(x,yPowrBase,':')
                pylab.plot(x,yPowrBase-yCorePowrBase*scaling,'--')
                pylab.plot(x,y,'-')
                pylab.show()
            
    if len(lsprPeakWLnmSubList) == 0: lsprPeakWLnmSubList.append( [0,0,0] )
    lsprPeakWLnmSubList = np.asarray(lsprPeakWLnmSubList)
    identifier = '_' + identifier0 + '_' + str(sampleNum) + '-' + sampleType
    filename = folder + timestamp + identifier + exportFormat
    #np.savetxt(filename, lsprPeakWLnmSubList, delimiter='\t', header=datHeader, fmt='%.2f')
    #print('      + saved to', filename) 

lsprMieCorePeakWLnmArray = np.asarray(lsprMieCorePeakWLnmList)
print('variable: \t lsprMieCorePeakWLnmArray')
print("  * output array format: \n    [ peak-wl-nm, gamma, nShell, sample-# ]")
print("    - sample-# = [0,...,5] \n      for [L1-Thin, L2-Med., L3-Thik, X1-Thin, X2-Med., X3-Thick]")
# Out:
# LSPR peak wavelengths
# =====================
# Core-shell nanoparticles
#   * looking for one peak at 535 nm
#     - in the range [ 522 , 548 ] nm
#     - baseline correction range [ 400 , 800 ] nm
# Peaks detected:
#     wl-nm,	 [wl-nm, ext, nShell] 	 gamma
#  * Sample # 0 ( L1-Thn )
#     523.32 ,	 [523.0, 221.23, 1.33] 	 1.000
#     524.37 ,	 [524.0, 234.0, 1.35] 	 1.024
#     525.45 ,	 [525.0, 247.18, 1.37] 	 1.048
#     526.57 ,	 [527.0, 260.77, 1.39] 	 1.073
#     527.7 ,	 [528.0, 274.75, 1.41] 	 1.098
#     528.87 ,	 [529.0, 289.05, 1.43] 	 1.124
#     530.07 ,	 [530.0, 303.64, 1.45] 	 1.150
#     531.33 ,	 [531.0, 318.46, 1.47] 	 1.177
#     532.65 ,	 [533.0, 333.5, 1.49] 	 1.204
#  * Sample # 1 ( L2-Med )
#     523.32 ,	 [523.0, 221.23, 1.33] 	 1.000
#     524.37 ,	 [524.0, 234.0, 1.35] 	 1.024
#     525.45 ,	 [525.0, 247.18, 1.37] 	 1.048
#     526.57 ,	 [527.0, 260.77, 1.39] 	 1.073
#     527.7 ,	 [528.0, 274.75, 1.41] 	 1.098
#     528.87 ,	 [529.0, 289.05, 1.43] 	 1.124
#     530.07 ,	 [530.0, 303.64, 1.45] 	 1.150
#     531.33 ,	 [531.0, 318.46, 1.47] 	 1.177
#     532.65 ,	 [533.0, 333.5, 1.49] 	 1.204
#  * Sample # 2 ( L3-Thk )
#     523.32 ,	 [523.0, 221.23, 1.33] 	 1.000
#     524.37 ,	 [524.0, 234.0, 1.35] 	 1.024
#     525.45 ,	 [525.0, 247.18, 1.37] 	 1.048
#     526.57 ,	 [527.0, 260.77, 1.39] 	 1.073
#     527.7 ,	 [528.0, 274.75, 1.41] 	 1.098
#     528.87 ,	 [529.0, 289.05, 1.43] 	 1.124
#     530.07 ,	 [530.0, 303.64, 1.45] 	 1.150
#     531.33 ,	 [531.0, 318.46, 1.47] 	 1.177
#     532.65 ,	 [533.0, 333.5, 1.49] 	 1.204
#  * Sample # 3 ( X1-Thn )
#     523.04 ,	 [523.0, 97.77, 1.33] 	 1.001
#     524.06 ,	 [524.0, 103.31, 1.35] 	 1.023
#     525.1 ,	 [525.0, 109.02, 1.37] 	 1.045
#     526.16 ,	 [526.0, 114.9, 1.39] 	 1.068
#     527.25 ,	 [527.0, 120.94, 1.41] 	 1.092
#     528.36 ,	 [528.0, 127.12, 1.43] 	 1.116
#     529.52 ,	 [529.0, 133.42, 1.45] 	 1.140
#     530.74 ,	 [531.0, 139.86, 1.47] 	 1.165
#     531.98 ,	 [532.0, 146.4, 1.49] 	 1.190
#  * Sample # 4 ( X2-Med )
#     523.04 ,	 [523.0, 97.77, 1.33] 	 1.001
#     524.06 ,	 [524.0, 103.31, 1.35] 	 1.023
#     525.1 ,	 [525.0, 109.02, 1.37] 	 1.045
#     526.16 ,	 [526.0, 114.9, 1.39] 	 1.068
#     527.25 ,	 [527.0, 120.94, 1.41] 	 1.092
#     528.36 ,	 [528.0, 127.12, 1.43] 	 1.116
#     529.52 ,	 [529.0, 133.42, 1.45] 	 1.140
#     530.74 ,	 [531.0, 139.86, 1.47] 	 1.165
#     531.98 ,	 [532.0, 146.4, 1.49] 	 1.190
#  * Sample # 5 ( X3-Thk )
#     523.04 ,	 [523.0, 97.77, 1.33] 	 1.001
#     524.06 ,	 [524.0, 103.31, 1.35] 	 1.023
#     525.1 ,	 [525.0, 109.02, 1.37] 	 1.045
#     526.16 ,	 [526.0, 114.9, 1.39] 	 1.068
#     527.25 ,	 [527.0, 120.94, 1.41] 	 1.092
#     528.36 ,	 [528.0, 127.12, 1.43] 	 1.116
#     529.52 ,	 [529.0, 133.42, 1.45] 	 1.140
#     530.74 ,	 [531.0, 139.86, 1.47] 	 1.165
#     531.98 ,	 [532.0, 146.4, 1.49] 	 1.190
# variable: 	 lsprMieCorePeakWLnmArray
#   * output array format:
#     [ peak-wl-nm, gamma, nShell, sample-# ]
#     - sample-# = [0,...,5]
#       for [L1-Thin, L2-Med., L3-Thik, X1-Thin, X2-Med., X3-Thick]

# %% [markdown]
# ## Peak wavelength plot

# %% [markdown]
# ### Simple, unformatted

# %%
for sampleNum in range(6):
    for nShell in nShellList:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        rCorenm = rCoreListnm[coreNum]
        
        subdataArray = lsprMiePowrPeakWLnmArray
        select = ( 
            (subdataArray[:,-1] == sampleNum) 
            & (subdataArray[:,-2] == nShell) 
        )
        subdataArray = subdataArray[select]
        sort = np.argsort(subdataArray[:,2])
        subdataArray = subdataArray[sort]
        
        x, y = subdataArray[:,0], subdataArray[:,2]/rCorenm
        label = str(sampleNum) + ', ' + str(np.round(nShell,2))
        pylab.semilogy(x,y, '.-', label=label)

        
        subdataArray = lsprMieSoftPowrPeakWLnmArray
        select = ( 
            (subdataArray[:,-1] == sampleNum) 
            & (subdataArray[:,-2] == nShell) 
        )
        subdataArray = subdataArray[select]
        sort = np.argsort(subdataArray[:,2])
        subdataArray = subdataArray[sort]

        x, y = subdataArray[:,0], subdataArray[:,2]/rCorenm
        label = label + ' (soft)'
        pylab.semilogy(x,y, '.:', label=label)


pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), ncol=3)
pylab.show()

# %% [markdown]
# ### Formatted

# %%
pylab.cla()

for coreNum in range(2):
    for nShell in nShellList:
        rCorenm = rCoreListnm[coreNum]
        
        for i in range(2):
            subdataArray = lsprMieSoftPowrPeakWLnmArray
            if i > 0: subdataArray = lsprMiePowrPeakWLnmArray
            select = ( 
                (subdataArray[:,-1] < 3) 
                & (subdataArray[:,-2] == nShell) 
            )
            if coreNum > 0:
                select = ( 
                    (subdataArray[:,-1] > 2) 
                    & (subdataArray[:,-2] == nShell) 
                )
            subdataArray = subdataArray[select]
            sort = np.argsort(subdataArray[:,2])
            subdataArray = subdataArray[sort]

            x, y = subdataArray[:,0], subdataArray[:,2]/rCorenm

            dx = np.diff(x)
            if dx[0] >= -.1:
                dx = np.concatenate((dx[[0]], dx)) 
                select = (nShell == nShellList[0]) | ( (dx > 0) & (x > 523) )
                x, y = x[select], y[select]

                label = str(coreNum) + ', ' + str(np.round(nShell,2)) 
                if i < 1: label = label + ' (soft)'
                colorFactor = (nShell-nShellList[0])/(nShellList[-1]-nShellList[0])
                color = cm.YlGn_r( 0.75*colorFactor )
                marker = ':'
                if i > 0: marker = '-'

                if ((i > 0) | (coreNum > 0)):
                    pylab.plot(x,np.log(y), marker, label=label, color=color)

for sampleNum in range(6):
    coreNum = 0
    if sampleNum > 2: coreNum = 1
    rCorenm = rCoreListnm[coreNum]
    
    for i in range(2):
        subdataArray = lsprPowrPeakWLnmArray
        select = (subdataArray[:,-1] == sampleNum)
        subdataArray = subdataArray[select]
        select = np.argsort(subdataArray[:,-2])[:2]
        if i > 0: select = np.argsort(subdataArray[:,-2])[-2:]
        subdataArray = subdataArray[select]
        x, y = subdataArray[:,0], subdataArray[:,-2]/rCorenm
        x, y = [np.mean(x)], [np.mean(y)]
        
        RgOverRh = (54/77 + 98/135 + 129/180)/3
        Radj = (sqrt(3/5).real)/RgOverRh

        #if i > 0: y = np.array(y)/Radj

        label = ['L1', 'L2', 'L3', 'X1', 'X2', 'X3'][sampleNum] + [' collapsed', ' swollen'][i]
        color = (['#ff0000','#cc0035','#990066','#660099','#3300cc','#0000ff'][sampleNum])
        marker = ['o','s'][i]

        pylab.plot(x,np.log(y), marker, label=label, color=color)

pylab.xlabel('Peak Wavelength [nm]')
pylab.ylabel('Shell-to-core ratio')
xlim = [522.1, 533.9]
pylab.xlim(xlim)
ylim = np.log(np.array([1.85,32.0]))
pylab.ylim(ylim)
xticks = np.arange(523, 534, 1)
xticklabels = []
for xtick in xticks: 
    if (np.mod(xtick,2) == 0): xticklabels.append(str(xtick))
    else: xticklabels.append('')
pylab.xticks(xticks, xticklabels)
yticks = np.arange(2, 30.5, 1)
yticklabels = []
for ytick in yticks: 
    if (ytick < 6) | (ytick == 7) | (np.mod(ytick,10) == 0): yticklabels.append(str(ytick))
    else: yticklabels.append('')
pylab.yticks(np.log(yticks), yticklabels)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), ncol=4)
aspect_ratio = 1.997/3.151
aspect = ( (xlim[1]-xlim[0])/(ylim[1]-ylim[0]) )/aspect_ratio
pylab.axes().set_aspect(aspect, adjustable='box')

## Save and display
timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.svg'
filename = ("graphics/" + timestamp 
            + "_mie_Ro-ratio-vs-lspr" 
            + exportFormat
            )
pylab.savefig(filename); print("Exported to:\n", filename)

pylab.show()
# Out:
# Exported to:
#  graphics/20170302_mie_Ro-ratio-vs-lspr.svg

# %% [markdown]
# ## Peak vs LSPR wavelength plot

# %% [markdown]
# ### Simple, unformatted

# %%
for sampleNum in range(6):
    for nShell in nShellList:
        coreNum = 0
        if sampleNum > 2: coreNum = 1
        rCorenm = rCoreListnm[coreNum]
        
        subdataArray = lsprMiePowrPeakWLnmArray
        select = ( 
            (subdataArray[:,-1] == sampleNum) 
            & (subdataArray[:,-2] == nShell) 
        )
        subdataArray = subdataArray[select]
        sort = np.argsort(subdataArray[:,2])
        subdataArray = subdataArray[sort]
        
        x = subdataArray[:,0]
        
        subdataArray = lsprMieCorePeakWLnmArray
        select = ( 
            (subdataArray[:,-1] == sampleNum) 
            & (subdataArray[:,-2] == nShell) 
        )
        subdataArray = subdataArray[select]
        sort = np.argsort(subdataArray[:,2])
        subdataArray = subdataArray[sort]
        
        y0 = subdataArray[0,0]
        y = np.ones_like(x)*y0
        
        label = str(sampleNum) + ', ' + str(np.round(nShell,2))
        pylab.plot(x,y, '.-', label=label)


x = np.unique(lsprMieCorePeakWLnmArray[:,0])
x = np.linspace(x[0]-1,x[-1]+1,5)
pylab.plot(x, x, '-', label='linear', color='gray')

pylab.xlabel('Peak Wavelength [nm]')
pylab.ylabel('LSPR Wavelength [nm]')

pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), ncol=3)
pylab.show()

# %% [markdown]
# ### Formatted, vs wavelength

# %%
pylab.cla()

for coreNum in range(2):
    for nShell in nShellList:
        rCorenm = rCoreListnm[coreNum]
        
        for i in range(2):
            subdataArray = lsprMieSoftPowrPeakWLnmArray
            if i > 0: subdataArray = lsprMiePowrPeakWLnmArray
            select = ( 
                (subdataArray[:,-1] < 3) 
                & (subdataArray[:,-2] == nShell) 
            )
            if coreNum > 0:
                select = ( 
                    (subdataArray[:,-1] > 2) 
                    & (subdataArray[:,-2] == nShell) 
                )
            subdataArray = subdataArray[select]
            sort = np.argsort(subdataArray[:,2])
            subdataArray = subdataArray[sort]

            x, y = subdataArray[:,0], subdataArray[:,2]/rCorenm
            y1 = y
            
            subdataArray1 = lsprMieCorePeakWLnmArray
            select = ( 
                (subdataArray1[:,-1] < 3) 
                & (subdataArray1[:,-2] == nShell) 
            )
            if coreNum > 0:
                select = ( 
                    (subdataArray1[:,-1] > 2) 
                    & (subdataArray1[:,-2] == nShell) 
                )
            subdataArray1 = subdataArray1[select]
            sort = np.argsort(subdataArray1[:,2])
            subdataArray1 = subdataArray1[sort]

            x0 = subdataArray1[0,0]
            x1 = np.ones_like(y1)*x0

            dx = np.diff(x)
            if dx[0] >= -.1:
                dx = np.concatenate((dx[[0]], dx)) 
                select = (nShell == nShellList[0]) | ( (dx > 0) & (x > 523) )
                x, y = x[select], y[select]

                label = str(coreNum) + ', ' + str(np.round(nShell,2)) 
                if i < 1: label = label + ' (soft)'
                colorFactor = (nShell-nShellList[0])/(nShellList[-1]-nShellList[0])
                color = cm.YlGn_r( 0.75*colorFactor )
                marker = ':'
                if i > 0: marker = '-'

                if ((i > 0) | (coreNum > 0)):
                    pylab.plot(x,np.log(y), marker, label=label, color=color)
                if ((i > 0) ):
                    label = str(coreNum) + ', ' + str(np.round(nShell,2)) + ' (core)'
                    pylab.plot(x1,np.log(y1), '--', label=label, color=color)

for sampleNum in range(6):
    coreNum = 0
    if sampleNum > 2: coreNum = 1
    rCorenm = rCoreListnm[coreNum]
    
    for i in range(2):
        subdataArray = lsprPowrPeakWLnmArray
        select = (subdataArray[:,-1] == sampleNum)
        subdataArray = subdataArray[select]
        select = np.argsort(subdataArray[:,-2])[:2]
        if i > 0: select = np.argsort(subdataArray[:,-2])[-2:]
        subdataArray = subdataArray[select]
        x, y = subdataArray[:,0], subdataArray[:,-2]/rCorenm
        x, y = [np.mean(x)], [np.mean(y)]
        
        RgOverRh = (54/77 + 98/135 + 129/180)/3
        Radj = (sqrt(3/5).real)/RgOverRh

        #if i > 0: y = np.array(y)/Radj

        label = ['L1', 'L2', 'L3', 'X1', 'X2', 'X3'][sampleNum] + [' collapsed', ' swollen'][i]
        color = (['#ff0000','#cc0035','#990066','#660099','#3300cc','#0000ff'][sampleNum])
        marker = ['o','s'][i]

        pylab.plot(x,np.log(y), marker, label=label, color=color)

pylab.xlabel('Peak Wavelength [nm]')
pylab.ylabel('Shell-to-core ratio')
xlim = [522.1, 533.9]
pylab.xlim(xlim)
ylim = np.log(np.array([1.85,32.0]))
pylab.ylim(ylim)
xticks = np.arange(523, 534, 1)
xticklabels = []
for xtick in xticks: 
    if (np.mod(xtick,2) == 0): xticklabels.append(str(xtick))
    else: xticklabels.append('')
pylab.xticks(xticks, xticklabels)
yticks = np.arange(2, 30.5, 1)
yticklabels = []
for ytick in yticks: 
    if (ytick < 6) | (ytick == 7) | (np.mod(ytick,10) == 0): yticklabels.append(str(ytick))
    else: yticklabels.append('')
pylab.yticks(np.log(yticks), yticklabels)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), ncol=3)
aspect_ratio = 1.997/3.151
aspect = ( (xlim[1]-xlim[0])/(ylim[1]-ylim[0]) )/aspect_ratio
pylab.axes().set_aspect(aspect, adjustable='box')

## Save and display
timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.svg'
filename = ("graphics/" + timestamp 
            + "_mie_Ro-ratio-vs-lspr_with-core-lspr" 
            + exportFormat
            )
pylab.savefig(filename); print("Exported to:\n", filename)

pylab.show()
# Out:
# Exported to:
#  graphics/20170302_mie_Ro-ratio-vs-lspr_with-core-lspr.svg

# %% [markdown]
# ### Formatted, vs change in wavelength

# %%
pylab.cla()

for coreNum in range(2):
    for nShell in nShellList:
        rCorenm = rCoreListnm[coreNum]
        
        for i in range(2):
            subdataArray = lsprMieSoftPowrPeakWLnmArray
            if i > 0: subdataArray = lsprMiePowrPeakWLnmArray
            select = ( 
                (subdataArray[:,-1] < 3) 
                & (subdataArray[:,-2] == nShell) 
            )
            if coreNum > 0:
                select = ( 
                    (subdataArray[:,-1] > 2) 
                    & (subdataArray[:,-2] == nShell) 
                )
            subdataArray = subdataArray[select]
            sort = np.argsort(subdataArray[:,2])
            subdataArray = subdataArray[sort]

            x, y = subdataArray[:,0], subdataArray[:,2]/rCorenm
            y1 = y
            
            subdataArray1 = lsprMieCorePeakWLnmArray
            select = ( 
                (subdataArray1[:,-1] < 3) 
                & (subdataArray1[:,-2] == nShell) 
            )
            if coreNum > 0:
                select = ( 
                    (subdataArray1[:,-1] > 2) 
                    & (subdataArray1[:,-2] == nShell) 
                )
            subdataArray1 = subdataArray1[select]
            sort = np.argsort(subdataArray1[:,2])
            subdataArray1 = subdataArray1[sort]

            x0 = subdataArray1[0,0]

            dx = np.diff(x)
            if dx[0] >= -.1:
                dx = np.concatenate((dx[[0]], dx)) 
                select = (nShell == nShellList[0]) | ( (dx > 0) & (x > 523) )
                x, y = x[select], y[select]

                label = str(coreNum) + ', ' + str(np.round(nShell,2)) 
                if i < 1: label = label + ' (soft)'
                colorFactor = (nShell-nShellList[0])/(nShellList[-1]-nShellList[0])
                color = cm.YlGn_r( 0.75*colorFactor )
                marker = ':'
                if i > 0: marker = '-'

                if ((i > 0) | (coreNum > 0)):
                    label = str(coreNum) + ', ' + str(np.round(nShell,2)) + ' (core)'
                    pylab.plot(x-x0,np.log(y), marker, label=label, color=color)


pylab.xlabel('LSPR - Peak Wavelength [nm]')
pylab.ylabel('Shell-to-core ratio')
xlim = [-2.5, 7.5]
pylab.xlim(xlim)
ylim = np.log(np.array([1.85,32.0]))
pylab.ylim(ylim)
xticks = np.arange(-2, 7.5, 1)
xticklabels = []
for xtick in xticks: 
    if (np.mod(xtick,2) == 0): xticklabels.append(str(xtick))
    else: xticklabels.append('')
pylab.xticks(xticks, xticklabels)
yticks = np.arange(2, 30.5, 1)
yticklabels = []
for ytick in yticks: 
    if (ytick < 6) | (ytick == 7) | (np.mod(ytick,10) == 0): yticklabels.append(str(ytick))
    else: yticklabels.append('')
pylab.yticks(np.log(yticks), yticklabels)
pylab.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), ncol=2)
aspect_ratio = 1.997/3.151
aspect = ( (xlim[1]-xlim[0])/(ylim[1]-ylim[0]) )/aspect_ratio
pylab.axes().set_aspect(aspect, adjustable='box')

## Save and display
timestamp = ('{:%Y%m%d}'.format(datetime.datetime.now()))
exportFormat = '.svg'
filename = ("graphics/" + timestamp 
            + "_mie_Ro-ratio-vs-dlspr-to-core_with-core-lspr" 
            + exportFormat
            )
pylab.savefig(filename); print("Exported to:\n", filename)

pylab.show()
# Out:
# Exported to:
#  graphics/20170302_mie_Ro-ratio-vs-dlspr-to-core_with-core-lspr.svg
